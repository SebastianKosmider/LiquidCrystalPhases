# %% [markdown]
# <a href="https://colab.research.google.com/github/SebastianKosmider/Praktyki/blob/main/Single_molecule_100x100_version_8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install h5py
# !pip install typing-extensions
# !pip install wheel
# Out:
# Requirement already satisfied: h5py in /usr/local/lib/python3.10/dist-packages (3.9.0)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.10/dist-packages (from h5py) (1.23.5)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (4.7.1)
# Requirement already satisfied: wheel in /usr/local/lib/python3.10/dist-packages (0.41.1)

# %%
# !pip install tensorflow==2.8
# Out:
# Collecting tensorflow==2.8
#   Downloading tensorflow-2.8.0-cp310-cp310-manylinux2010_x86_64.whl (497.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 497.6/497.6 MB 3.1 MB/s eta 0:00:00
# Requirement already satisfied: absl-py>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8) (1.6.3)
# Requirement already satisfied: flatbuffers>=1.12 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8) (23.5.26)
# Requirement already satisfied: gast>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8) (0.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8) (3.9.0)
# Collecting keras-preprocessing>=1.1.1 (from tensorflow==2.8)
#   Downloading Keras_Preprocessing-1.1.2-py2.py3-none-any.whl (42 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.6/42.6 kB 4.8 MB/s eta 0:00:00
# Requirement already satisfied: libclang>=9.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8) (16.0.6)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8) (1.23.5)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8) (3.3.0)
# Requirement already satisfied: protobuf>=3.9.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8) (3.20.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8) (67.7.2)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8) (2.3.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8) (4.7.1)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8) (1.14.1)
# Collecting tensorboard<2.9,>=2.8 (from tensorflow==2.8)
#   Downloading tensorboard-2.8.0-py3-none-any.whl (5.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.8/5.8 MB 115.6 MB/s eta 0:00:00
# Collecting tf-estimator-nightly==2.8.0.dev2021122109 (from tensorflow==2.8)
#   Downloading tf_estimator_nightly-2.8.0.dev2021122109-py2.py3-none-any.whl (462 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 462.5/462.5 kB 39.5 MB/s eta 0:00:00
# Collecting keras<2.9,>=2.8.0rc0 (from tensorflow==2.8)
#   Downloading keras-2.8.0-py2.py3-none-any.whl (1.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 73.4 MB/s eta 0:00:00
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8) (0.33.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8) (1.57.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow==2.8) (0.41.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.9,>=2.8->tensorflow==2.8) (2.17.3)
# Collecting google-auth-oauthlib<0.5,>=0.4.1 (from tensorboard<2.9,>=2.8->tensorflow==2.8)
#   Downloading google_auth_oauthlib-0.4.6-py2.py3-none-any.whl (18 kB)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.9,>=2.8->tensorflow==2.8) (3.4.4)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.9,>=2.8->tensorflow==2.8) (2.31.0)
# Collecting tensorboard-data-server<0.7.0,>=0.6.0 (from tensorboard<2.9,>=2.8->tensorflow==2.8)
#   Downloading tensorboard_data_server-0.6.1-py3-none-manylinux2010_x86_64.whl (4.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 93.0 MB/s eta 0:00:00
# Collecting tensorboard-plugin-wit>=1.6.0 (from tensorboard<2.9,>=2.8->tensorflow==2.8)
#   Downloading tensorboard_plugin_wit-1.8.1-py3-none-any.whl (781 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 781.3/781.3 kB 59.8 MB/s eta 0:00:00
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.9,>=2.8->tensorflow==2.8) (2.3.6)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow==2.8) (5.3.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow==2.8) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow==2.8) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow==2.8) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow==2.8) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow==2.8) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow==2.8) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow==2.8) (2023.7.22)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=0.11.15->tensorboard<2.9,>=2.8->tensorflow==2.8) (2.1.3)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow==2.8) (0.5.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow==2.8) (3.2.2)
# Installing collected packages: tf-estimator-nightly, tensorboard-plugin-wit, keras, tensorboard-data-server, keras-preprocessing, google-auth-oauthlib, tensorboard, tensorflow
#   Attempting uninstall: keras
#     Found existing installation: keras 2.12.0
#     Uninstalling keras-2.12.0:
#       Successfully uninstalled keras-2.12.0
#   Attempting uninstall: tensorboard-data-server
#     Found existing installation: tensorboard-data-server 0.7.1
#     Uninstalling tensorboard-data-server-0.7.1:
#       Successfully uninstalled tensorboard-data-server-0.7.1
#   Attempting uninstall: google-auth-oauthlib
#     Found existing installation: google-auth-oauthlib 1.0.0
#     Uninstalling google-auth-oauthlib-1.0.0:
#       Successfully uninstalled google-auth-oauthlib-1.0.0
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.12.3
#     Uninstalling tensorboard-2.12.3:
#       Successfully uninstalled tensorboard-2.12.3
#   Attempting uninstall: tensorflow
#     Found existing installation: tensorflow 2.12.0
#     Uninstalling tensorflow-2.12.0:
#       Successfully uninstalled tensorflow-2.12.0
# Successfully installed google-auth-oauthlib-0.4.6 keras-2.8.0 keras-preprocessing-1.1.2 tensorboard-2.8.0 tensorboard-data-server-0.6.1 tensorboard-plugin-wit-1.8.1 tensorflow-2.8.0 tf-estimator-nightly-2.8.0.dev2021122109

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import zipfile
import numpy as np
import cv2
from google.colab.patches import cv2_imshow
import tensorflow as tf
from tensorflow.keras.callbacks import ReduceLROnPlateau
from tensorflow.keras import regularizers
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPool2D, Flatten, Dense, BatchNormalization, Dropout
from tensorflow.keras.preprocessing.image import ImageDataGenerator
tf.__version__
# Out:
# '2.8.0'

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
path = '/content/drive/MyDrive/praktyki/rawDataSingleMolecule/gotowe.zip'
zip_object = zipfile.ZipFile(file=path, mode='r')
zip_object.extractall('./')
zip_object.close()

# %%
training_generator = ImageDataGenerator(rescale=1./255,
                                        horizontal_flip=True,
                                        vertical_flip=True)

# %%
train_dataset = training_generator.flow_from_directory('/content/gotowe/train_set',
                                                       target_size = (100, 100),
                                                       batch_size = 10,
                                                       color_mode='rgb',
                                                       class_mode = 'categorical',
                                                       shuffle = True)
# Out:
# Found 11158 images belonging to 7 classes.

# %%
train_dataset.classes
# Out:
# array([0, 0, 0, ..., 6, 6, 6], dtype=int32)

# %%
train_dataset.class_indices
# Out:
# {'nematyk': 0,
#  'smektyk_C': 1,
#  'smektyk_F': 2,
#  'smektyk_GMosaic': 3,
#  'smektyk_GSchliren': 4,
#  'smektyk_H': 5,
#  'smektyk_I': 6}

# %%
test_generator = ImageDataGenerator(rescale=1./255)
val_generator = ImageDataGenerator(rescale=1./255)

# %%
validation_dataset = val_generator.flow_from_directory('/content/gotowe/val_set',
                                                        target_size=(100, 100),
                                                        batch_size=1,
                                                        class_mode='categorical',
                                                        color_mode='rgb',
                                                        shuffle=True) # set as validation data
# Out:
# Found 1395 images belonging to 7 classes.

# %%
L2 = 0.00001

# %%
test_datatset = test_generator.flow_from_directory('/content/gotowe/test_set',
                                                   target_size = (100, 100),
                                                   batch_size = 1,
                                                   color_mode='rgb',
                                                   class_mode = 'categorical',
                                                   shuffle = False)
# Out:
# Found 1396 images belonging to 7 classes.

# %%
initializer1 = tf.keras.initializers.HeNormal()
initializer2 = tf.keras.initializers.GlorotUniform()

# %%
network = Sequential()
network.add(Conv2D(filters=16, kernel_size=(3,3), activation = 'relu', input_shape = (100,100,3), kernel_initializer=initializer1))
network.add(Conv2D(filters=16, kernel_size=(3,3), activation = 'relu', padding='same', kernel_initializer=initializer1))
network.add(Conv2D(filters=16, kernel_size=(3,3), activation = 'relu', padding='same', kernel_initializer=initializer1))
network.add(BatchNormalization())
network.add(MaxPool2D(pool_size=(2,2)))

network.add(Conv2D(filters=32, kernel_size=(3,3), activation = 'relu', padding='same', kernel_initializer=initializer1))
network.add(Conv2D(filters=32, kernel_size=(3,3), activation = 'relu', padding='same', kernel_initializer=initializer1))
network.add(BatchNormalization())
network.add(MaxPool2D(pool_size=(2,2)))

network.add(Conv2D(filters=64, kernel_size=(3,3), activation = 'relu', padding='same', kernel_initializer=initializer1))
network.add(BatchNormalization())
network.add(MaxPool2D(pool_size=(2,2)))

network.add(Conv2D(filters=128, kernel_size=(3,3), activation = 'relu', padding='same', kernel_initializer=initializer1))
network.add(Conv2D(filters=128, kernel_size=(3,3), activation = 'relu', padding='same', kernel_initializer=initializer1))
network.add(BatchNormalization())
network.add(MaxPool2D(pool_size=(2,2)))

network.add(Conv2D(filters=256, kernel_size=(1,1), activation = 'relu', padding='same', kernel_initializer=initializer1))
network.add(BatchNormalization())
network.add(MaxPool2D(pool_size=(2,2)))

network.add(Conv2D(filters=512, kernel_size=(1,1), activation = 'relu', padding='same', kernel_initializer=initializer1))
network.add(Conv2D(filters=512, kernel_size=(1,1), activation = 'relu', padding='same', kernel_initializer=initializer1))
network.add(BatchNormalization())
network.add(MaxPool2D(pool_size=(2,2)))

network.add(Flatten())

network.add(Dropout(0.07))

network.add(Dense(units = 64, activation = 'relu', kernel_initializer=initializer1))
network.add(BatchNormalization())
network.add(Dense(units = 64, activation = 'relu', kernel_initializer=initializer1))
network.add(BatchNormalization())
network.add(Dense(units = 32, activation = 'relu', kernel_initializer=initializer1))
network.add(BatchNormalization())
network.add(Dense(units = 16, activation = 'relu', kernel_initializer=initializer1, kernel_regularizer=tf.keras.regularizers.L1L2()))
network.add(BatchNormalization())
network.add(Dense(units = 7, activation = 'softmax', kernel_initializer=initializer2))
network.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 98, 98, 16)        448
#
#  conv2d_1 (Conv2D)           (None, 98, 98, 16)        2320
#
#  conv2d_2 (Conv2D)           (None, 98, 98, 16)        2320
#
#  batch_normalization (BatchN  (None, 98, 98, 16)       64
#  ormalization)
#
#  max_pooling2d (MaxPooling2D  (None, 49, 49, 16)       0
#  )
#
#  conv2d_3 (Conv2D)           (None, 49, 49, 32)        4640
#
#  conv2d_4 (Conv2D)           (None, 49, 49, 32)        9248
#
#  batch_normalization_1 (Batc  (None, 49, 49, 32)       128
#  hNormalization)
#
#  max_pooling2d_1 (MaxPooling  (None, 24, 24, 32)       0
#  2D)
#
#  conv2d_5 (Conv2D)           (None, 24, 24, 64)        18496
#
#  batch_normalization_2 (Batc  (None, 24, 24, 64)       256
#  hNormalization)
#
#  max_pooling2d_2 (MaxPooling  (None, 12, 12, 64)       0
#  2D)
#
#  conv2d_6 (Conv2D)           (None, 12, 12, 128)       73856
#
#  conv2d_7 (Conv2D)           (None, 12, 12, 128)       147584
#
#  batch_normalization_3 (Batc  (None, 12, 12, 128)      512
#  hNormalization)
#
#  max_pooling2d_3 (MaxPooling  (None, 6, 6, 128)        0
#  2D)
#
#  conv2d_8 (Conv2D)           (None, 6, 6, 256)         33024
#
#  batch_normalization_4 (Batc  (None, 6, 6, 256)        1024
#  hNormalization)
#
#  max_pooling2d_4 (MaxPooling  (None, 3, 3, 256)        0
#  2D)
#
#  conv2d_9 (Conv2D)           (None, 3, 3, 512)         131584
#
#  conv2d_10 (Conv2D)          (None, 3, 3, 512)         262656
#
#  batch_normalization_5 (Batc  (None, 3, 3, 512)        2048
#  hNormalization)
#
#  max_pooling2d_5 (MaxPooling  (None, 1, 1, 512)        0
#  2D)
#
#  flatten (Flatten)           (None, 512)               0
#
#  dropout (Dropout)           (None, 512)               0
#
#  dense (Dense)               (None, 64)                32832
#
#  batch_normalization_6 (Batc  (None, 64)               256
#  hNormalization)
#
#  dense_1 (Dense)             (None, 64)                4160
#
#  batch_normalization_7 (Batc  (None, 64)               256
#  hNormalization)
#
#  dense_2 (Dense)             (None, 32)                2080
#
#  batch_normalization_8 (Batc  (None, 32)               128
#  hNormalization)
#
#  dense_3 (Dense)             (None, 16)                528
#
#  batch_normalization_9 (Batc  (None, 16)               64
#  hNormalization)
#
#  dense_4 (Dense)             (None, 7)                 119
#
# =================================================================
# Total params: 730,631
# Trainable params: 728,263
# Non-trainable params: 2,368
# _________________________________________________________________

# %%
from tensorflow.keras.optimizers import Adam
#opt = Adam(lr=0.005)
opt = Adam()
network.compile(optimizer='Adam', loss='categorical_crossentropy', metrics = ['accuracy'])

# %%
es = EarlyStopping(monitor = 'val_accuracy', min_delta = 0.001, patience = 20, verbose =1)
model_cp = ModelCheckpoint(filepath = 'best_model8.h5', monitor = 'val_accuracy', save_best_only = True, verbose = 1)
learning_rate_reduction = ReduceLROnPlateau(monitor='val_accuracy', patience = 5, verbose=1, factor=0.5, min_lr=0.00001)

# %%
history = network.fit_generator(train_dataset,
                                steps_per_epoch = 50,
                                validation_data = validation_dataset,
                                validation_steps = 50,
                                epochs=100,
                                callbacks=[es, model_cp, learning_rate_reduction])
# Out:
# Epoch 1/100
# <ipython-input-18-d45876fe1552>:1: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history = network.fit_generator(train_dataset,
# 50/50 [==============================] - ETA: 0s - loss: 2.1507 - accuracy: 0.2020
# Epoch 1: val_accuracy improved from -inf to 0.12000, saving model to best_model8.h5
# 50/50 [==============================] - 18s 318ms/step - loss: 2.1507 - accuracy: 0.2020 - val_loss: 2.0401 - val_accuracy: 0.1200 - lr: 0.0010
# Epoch 2/100
# 50/50 [==============================] - ETA: 0s - loss: 1.6909 - accuracy: 0.3660
# Epoch 2: val_accuracy improved from 0.12000 to 0.26000, saving model to best_model8.h5
# 50/50 [==============================] - 17s 334ms/step - loss: 1.6909 - accuracy: 0.3660 - val_loss: 1.9173 - val_accuracy: 0.2600 - lr: 0.0010
# Epoch 3/100
# 50/50 [==============================] - ETA: 0s - loss: 1.6198 - accuracy: 0.3720
# Epoch 3: val_accuracy did not improve from 0.26000
# 50/50 [==============================] - 15s 304ms/step - loss: 1.6198 - accuracy: 0.3720 - val_loss: 1.9368 - val_accuracy: 0.1800 - lr: 0.0010
# Epoch 4/100
# 50/50 [==============================] - ETA: 0s - loss: 1.6662 - accuracy: 0.3640
# Epoch 4: val_accuracy did not improve from 0.26000
# 50/50 [==============================] - 15s 305ms/step - loss: 1.6662 - accuracy: 0.3640 - val_loss: 1.9301 - val_accuracy: 0.2000 - lr: 0.0010
# Epoch 5/100
# 50/50 [==============================] - ETA: 0s - loss: 1.4528 - accuracy: 0.4400
# Epoch 5: val_accuracy did not improve from 0.26000
# 50/50 [==============================] - 15s 307ms/step - loss: 1.4528 - accuracy: 0.4400 - val_loss: 1.7584 - val_accuracy: 0.2600 - lr: 0.0010
# Epoch 6/100
# 50/50 [==============================] - ETA: 0s - loss: 1.4385 - accuracy: 0.4740
# Epoch 6: val_accuracy improved from 0.26000 to 0.46000, saving model to best_model8.h5
# 50/50 [==============================] - 15s 307ms/step - loss: 1.4385 - accuracy: 0.4740 - val_loss: 1.7794 - val_accuracy: 0.4600 - lr: 0.0010
# Epoch 7/100
# 50/50 [==============================] - ETA: 0s - loss: 1.4243 - accuracy: 0.4420
# Epoch 7: val_accuracy did not improve from 0.46000
# 50/50 [==============================] - 15s 306ms/step - loss: 1.4243 - accuracy: 0.4420 - val_loss: 1.5608 - val_accuracy: 0.4200 - lr: 0.0010
# Epoch 8/100
# 50/50 [==============================] - ETA: 0s - loss: 1.3569 - accuracy: 0.4920
# Epoch 8: val_accuracy did not improve from 0.46000
# 50/50 [==============================] - 15s 308ms/step - loss: 1.3569 - accuracy: 0.4920 - val_loss: 1.3744 - val_accuracy: 0.4000 - lr: 0.0010
# Epoch 9/100
# 50/50 [==============================] - ETA: 0s - loss: 1.2853 - accuracy: 0.5020
# Epoch 9: val_accuracy improved from 0.46000 to 0.48000, saving model to best_model8.h5
# 50/50 [==============================] - 16s 309ms/step - loss: 1.2853 - accuracy: 0.5020 - val_loss: 1.2040 - val_accuracy: 0.4800 - lr: 0.0010
# Epoch 10/100
# 50/50 [==============================] - ETA: 0s - loss: 1.2965 - accuracy: 0.4860
# Epoch 10: val_accuracy did not improve from 0.48000
# 50/50 [==============================] - 16s 316ms/step - loss: 1.2965 - accuracy: 0.4860 - val_loss: 2.0511 - val_accuracy: 0.3800 - lr: 0.0010
# Epoch 11/100
# 50/50 [==============================] - ETA: 0s - loss: 1.2863 - accuracy: 0.5220
# Epoch 11: val_accuracy improved from 0.48000 to 0.50000, saving model to best_model8.h5
# 50/50 [==============================] - 15s 306ms/step - loss: 1.2863 - accuracy: 0.5220 - val_loss: 1.2546 - val_accuracy: 0.5000 - lr: 0.0010
# Epoch 12/100
# 50/50 [==============================] - ETA: 0s - loss: 1.3258 - accuracy: 0.5080
# Epoch 12: val_accuracy did not improve from 0.50000
# 50/50 [==============================] - 15s 305ms/step - loss: 1.3258 - accuracy: 0.5080 - val_loss: 1.2554 - val_accuracy: 0.4600 - lr: 0.0010
# Epoch 13/100
# 50/50 [==============================] - ETA: 0s - loss: 1.1661 - accuracy: 0.5560
# Epoch 13: val_accuracy improved from 0.50000 to 0.52000, saving model to best_model8.h5
# 50/50 [==============================] - 17s 349ms/step - loss: 1.1661 - accuracy: 0.5560 - val_loss: 1.1994 - val_accuracy: 0.5200 - lr: 0.0010
# Epoch 14/100
# 50/50 [==============================] - ETA: 0s - loss: 1.1743 - accuracy: 0.5540
# Epoch 14: val_accuracy improved from 0.52000 to 0.64000, saving model to best_model8.h5
# 50/50 [==============================] - 15s 309ms/step - loss: 1.1743 - accuracy: 0.5540 - val_loss: 1.0690 - val_accuracy: 0.6400 - lr: 0.0010
# Epoch 15/100
# 50/50 [==============================] - ETA: 0s - loss: 1.2598 - accuracy: 0.5580
# Epoch 15: val_accuracy did not improve from 0.64000
# 50/50 [==============================] - 15s 309ms/step - loss: 1.2598 - accuracy: 0.5580 - val_loss: 1.3378 - val_accuracy: 0.5000 - lr: 0.0010
# Epoch 16/100
# 50/50 [==============================] - ETA: 0s - loss: 1.1451 - accuracy: 0.5940
# Epoch 16: val_accuracy did not improve from 0.64000
# 50/50 [==============================] - 16s 307ms/step - loss: 1.1451 - accuracy: 0.5940 - val_loss: 1.2079 - val_accuracy: 0.5400 - lr: 0.0010
# Epoch 17/100
# 50/50 [==============================] - ETA: 0s - loss: 1.1563 - accuracy: 0.6100
# Epoch 17: val_accuracy did not improve from 0.64000
# 50/50 [==============================] - 15s 306ms/step - loss: 1.1563 - accuracy: 0.6100 - val_loss: 1.0199 - val_accuracy: 0.6200 - lr: 0.0010
# Epoch 18/100
# 50/50 [==============================] - ETA: 0s - loss: 1.0765 - accuracy: 0.5920
# Epoch 18: val_accuracy did not improve from 0.64000
# 50/50 [==============================] - 15s 306ms/step - loss: 1.0765 - accuracy: 0.5920 - val_loss: 1.3838 - val_accuracy: 0.5400 - lr: 0.0010
# Epoch 19/100
# 50/50 [==============================] - ETA: 0s - loss: 1.1725 - accuracy: 0.5780
# Epoch 19: val_accuracy improved from 0.64000 to 0.66000, saving model to best_model8.h5
# 50/50 [==============================] - 17s 336ms/step - loss: 1.1725 - accuracy: 0.5780 - val_loss: 0.8318 - val_accuracy: 0.6600 - lr: 0.0010
# Epoch 20/100
# 50/50 [==============================] - ETA: 0s - loss: 1.0549 - accuracy: 0.6260
# Epoch 20: val_accuracy did not improve from 0.66000
# 50/50 [==============================] - 15s 308ms/step - loss: 1.0549 - accuracy: 0.6260 - val_loss: 1.1665 - val_accuracy: 0.5600 - lr: 0.0010
# Epoch 21/100
# 50/50 [==============================] - ETA: 0s - loss: 1.0183 - accuracy: 0.6540
# Epoch 21: val_accuracy did not improve from 0.66000
# 50/50 [==============================] - 16s 310ms/step - loss: 1.0183 - accuracy: 0.6540 - val_loss: 1.0176 - val_accuracy: 0.6600 - lr: 0.0010
# Epoch 22/100
# 50/50 [==============================] - ETA: 0s - loss: 1.1539 - accuracy: 0.5760
# Epoch 22: val_accuracy did not improve from 0.66000
# 50/50 [==============================] - 16s 312ms/step - loss: 1.1539 - accuracy: 0.5760 - val_loss: 0.8586 - val_accuracy: 0.6000 - lr: 0.0010
# Epoch 23/100
# 50/50 [==============================] - ETA: 0s - loss: 1.0371 - accuracy: 0.6220
# Epoch 23: val_accuracy improved from 0.66000 to 0.68000, saving model to best_model8.h5
# 50/50 [==============================] - 15s 309ms/step - loss: 1.0371 - accuracy: 0.6220 - val_loss: 0.8939 - val_accuracy: 0.6800 - lr: 0.0010
# Epoch 24/100
# 50/50 [==============================] - ETA: 0s - loss: 1.1216 - accuracy: 0.5680
# Epoch 24: val_accuracy did not improve from 0.68000
# 50/50 [==============================] - 15s 310ms/step - loss: 1.1216 - accuracy: 0.5680 - val_loss: 1.0513 - val_accuracy: 0.6600 - lr: 0.0010
# Epoch 25/100
# 50/50 [==============================] - ETA: 0s - loss: 1.0955 - accuracy: 0.5700
# Epoch 25: val_accuracy improved from 0.68000 to 0.76000, saving model to best_model8.h5
# 50/50 [==============================] - 16s 314ms/step - loss: 1.0955 - accuracy: 0.5700 - val_loss: 0.7338 - val_accuracy: 0.7600 - lr: 0.0010
# Epoch 26/100
# 50/50 [==============================] - ETA: 0s - loss: 1.0896 - accuracy: 0.6140
# Epoch 26: val_accuracy did not improve from 0.76000
# 50/50 [==============================] - 15s 307ms/step - loss: 1.0896 - accuracy: 0.6140 - val_loss: 0.7671 - val_accuracy: 0.7600 - lr: 0.0010
# Epoch 27/100
# 50/50 [==============================] - ETA: 0s - loss: 1.1097 - accuracy: 0.6000
# Epoch 27: val_accuracy did not improve from 0.76000
# 50/50 [==============================] - 15s 308ms/step - loss: 1.1097 - accuracy: 0.6000 - val_loss: 1.3950 - val_accuracy: 0.4600 - lr: 0.0010
# Epoch 28/100
# 50/50 [==============================] - ETA: 0s - loss: 0.9842 - accuracy: 0.6580
# Epoch 28: val_accuracy did not improve from 0.76000
# 50/50 [==============================] - 16s 312ms/step - loss: 0.9842 - accuracy: 0.6580 - val_loss: 0.9137 - val_accuracy: 0.6800 - lr: 0.0010
# Epoch 29/100
# 50/50 [==============================] - ETA: 0s - loss: 0.9457 - accuracy: 0.6640
# Epoch 29: val_accuracy did not improve from 0.76000
# 50/50 [==============================] - 16s 312ms/step - loss: 0.9457 - accuracy: 0.6640 - val_loss: 0.9768 - val_accuracy: 0.6400 - lr: 0.0010
# Epoch 30/100
# 50/50 [==============================] - ETA: 0s - loss: 0.9330 - accuracy: 0.6460
# Epoch 30: val_accuracy improved from 0.76000 to 0.80000, saving model to best_model8.h5
# 50/50 [==============================] - 16s 315ms/step - loss: 0.9330 - accuracy: 0.6460 - val_loss: 0.5850 - val_accuracy: 0.8000 - lr: 0.0010
# Epoch 31/100
# 50/50 [==============================] - ETA: 0s - loss: 0.9364 - accuracy: 0.6760
# Epoch 31: val_accuracy did not improve from 0.80000
# 50/50 [==============================] - 16s 310ms/step - loss: 0.9364 - accuracy: 0.6760 - val_loss: 0.8073 - val_accuracy: 0.7400 - lr: 0.0010
# Epoch 32/100
# 50/50 [==============================] - ETA: 0s - loss: 1.0108 - accuracy: 0.6640
# Epoch 32: val_accuracy did not improve from 0.80000
# 50/50 [==============================] - 16s 311ms/step - loss: 1.0108 - accuracy: 0.6640 - val_loss: 0.6953 - val_accuracy: 0.8000 - lr: 0.0010
# Epoch 33/100
# 50/50 [==============================] - ETA: 0s - loss: 0.9668 - accuracy: 0.6740
# Epoch 33: val_accuracy did not improve from 0.80000
# 50/50 [==============================] - 16s 311ms/step - loss: 0.9668 - accuracy: 0.6740 - val_loss: 0.9054 - val_accuracy: 0.7000 - lr: 0.0010
# Epoch 34/100
# 50/50 [==============================] - ETA: 0s - loss: 0.9628 - accuracy: 0.6580
# Epoch 34: val_accuracy did not improve from 0.80000
# 50/50 [==============================] - 15s 309ms/step - loss: 0.9628 - accuracy: 0.6580 - val_loss: 0.8474 - val_accuracy: 0.6800 - lr: 0.0010
# Epoch 35/100
# 50/50 [==============================] - ETA: 0s - loss: 1.0608 - accuracy: 0.6400
# Epoch 35: val_accuracy did not improve from 0.80000
#
# Epoch 35: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 50/50 [==============================] - 16s 311ms/step - loss: 1.0608 - accuracy: 0.6400 - val_loss: 0.7566 - val_accuracy: 0.7800 - lr: 0.0010
# Epoch 36/100
# 50/50 [==============================] - ETA: 0s - loss: 1.0570 - accuracy: 0.6260
# Epoch 36: val_accuracy did not improve from 0.80000
# 50/50 [==============================] - 15s 311ms/step - loss: 1.0570 - accuracy: 0.6260 - val_loss: 0.7537 - val_accuracy: 0.7000 - lr: 5.0000e-04
# Epoch 37/100
# 50/50 [==============================] - ETA: 0s - loss: 0.9082 - accuracy: 0.6580
# Epoch 37: val_accuracy did not improve from 0.80000
# 50/50 [==============================] - 16s 318ms/step - loss: 0.9082 - accuracy: 0.6580 - val_loss: 0.7596 - val_accuracy: 0.7400 - lr: 5.0000e-04
# Epoch 38/100
# 50/50 [==============================] - ETA: 0s - loss: 1.0011 - accuracy: 0.6400
# Epoch 38: val_accuracy did not improve from 0.80000
# 50/50 [==============================] - 16s 314ms/step - loss: 1.0011 - accuracy: 0.6400 - val_loss: 0.6328 - val_accuracy: 0.8000 - lr: 5.0000e-04
# Epoch 39/100
# 50/50 [==============================] - ETA: 0s - loss: 0.9138 - accuracy: 0.6540
# Epoch 39: val_accuracy did not improve from 0.80000
# 50/50 [==============================] - 15s 309ms/step - loss: 0.9138 - accuracy: 0.6540 - val_loss: 0.7426 - val_accuracy: 0.7200 - lr: 5.0000e-04
# Epoch 40/100
# 50/50 [==============================] - ETA: 0s - loss: 1.0145 - accuracy: 0.6340
# Epoch 40: val_accuracy did not improve from 0.80000
#
# Epoch 40: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 50/50 [==============================] - 15s 308ms/step - loss: 1.0145 - accuracy: 0.6340 - val_loss: 0.8282 - val_accuracy: 0.6600 - lr: 5.0000e-04
# Epoch 41/100
# 50/50 [==============================] - ETA: 0s - loss: 0.9518 - accuracy: 0.6440
# Epoch 41: val_accuracy did not improve from 0.80000
# 50/50 [==============================] - 16s 311ms/step - loss: 0.9518 - accuracy: 0.6440 - val_loss: 0.7764 - val_accuracy: 0.7800 - lr: 2.5000e-04
# Epoch 42/100
# 50/50 [==============================] - ETA: 0s - loss: 0.9472 - accuracy: 0.6500
# Epoch 42: val_accuracy did not improve from 0.80000
# 50/50 [==============================] - 17s 351ms/step - loss: 0.9472 - accuracy: 0.6500 - val_loss: 0.5440 - val_accuracy: 0.8000 - lr: 2.5000e-04
# Epoch 43/100
# 50/50 [==============================] - ETA: 0s - loss: 0.8291 - accuracy: 0.7260
# Epoch 43: val_accuracy improved from 0.80000 to 0.86000, saving model to best_model8.h5
# 50/50 [==============================] - 16s 312ms/step - loss: 0.8291 - accuracy: 0.7260 - val_loss: 0.5803 - val_accuracy: 0.8600 - lr: 2.5000e-04
# Epoch 44/100
# 50/50 [==============================] - ETA: 0s - loss: 0.8509 - accuracy: 0.7020
# Epoch 44: val_accuracy did not improve from 0.86000
# 50/50 [==============================] - 16s 311ms/step - loss: 0.8509 - accuracy: 0.7020 - val_loss: 0.7338 - val_accuracy: 0.7600 - lr: 2.5000e-04
# Epoch 45/100
# 50/50 [==============================] - ETA: 0s - loss: 0.8910 - accuracy: 0.6780
# Epoch 45: val_accuracy did not improve from 0.86000
# 50/50 [==============================] - 15s 309ms/step - loss: 0.8910 - accuracy: 0.6780 - val_loss: 0.6535 - val_accuracy: 0.8400 - lr: 2.5000e-04
# Epoch 46/100
# 50/50 [==============================] - ETA: 0s - loss: 0.9309 - accuracy: 0.6640
# Epoch 46: val_accuracy did not improve from 0.86000
# 50/50 [==============================] - 16s 312ms/step - loss: 0.9309 - accuracy: 0.6640 - val_loss: 0.7335 - val_accuracy: 0.7800 - lr: 2.5000e-04
# Epoch 47/100
# 50/50 [==============================] - ETA: 0s - loss: 0.8859 - accuracy: 0.6880
# Epoch 47: val_accuracy did not improve from 0.86000
# 50/50 [==============================] - 16s 312ms/step - loss: 0.8859 - accuracy: 0.6880 - val_loss: 0.8900 - val_accuracy: 0.7600 - lr: 2.5000e-04
# Epoch 48/100
# 50/50 [==============================] - ETA: 0s - loss: 0.8560 - accuracy: 0.7180
# Epoch 48: val_accuracy did not improve from 0.86000
#
# Epoch 48: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 50/50 [==============================] - 16s 313ms/step - loss: 0.8560 - accuracy: 0.7180 - val_loss: 0.6931 - val_accuracy: 0.8000 - lr: 2.5000e-04
# Epoch 49/100
# 50/50 [==============================] - ETA: 0s - loss: 0.8532 - accuracy: 0.7120
# Epoch 49: val_accuracy did not improve from 0.86000
# 50/50 [==============================] - 16s 311ms/step - loss: 0.8532 - accuracy: 0.7120 - val_loss: 0.5750 - val_accuracy: 0.8000 - lr: 1.2500e-04
# Epoch 50/100
# 50/50 [==============================] - ETA: 0s - loss: 0.7933 - accuracy: 0.7480
# Epoch 50: val_accuracy did not improve from 0.86000
# 50/50 [==============================] - 16s 314ms/step - loss: 0.7933 - accuracy: 0.7480 - val_loss: 0.7841 - val_accuracy: 0.7600 - lr: 1.2500e-04
# Epoch 51/100
# 50/50 [==============================] - ETA: 0s - loss: 0.7763 - accuracy: 0.7360
# Epoch 51: val_accuracy did not improve from 0.86000
# 50/50 [==============================] - 17s 338ms/step - loss: 0.7763 - accuracy: 0.7360 - val_loss: 0.7683 - val_accuracy: 0.7400 - lr: 1.2500e-04
# Epoch 52/100
# 50/50 [==============================] - ETA: 0s - loss: 0.8364 - accuracy: 0.7200
# Epoch 52: val_accuracy did not improve from 0.86000
# 50/50 [==============================] - 16s 314ms/step - loss: 0.8364 - accuracy: 0.7200 - val_loss: 0.5763 - val_accuracy: 0.7400 - lr: 1.2500e-04
# Epoch 53/100
# 50/50 [==============================] - ETA: 0s - loss: 0.8336 - accuracy: 0.7220
# Epoch 53: val_accuracy improved from 0.86000 to 0.90000, saving model to best_model8.h5
# 50/50 [==============================] - 16s 314ms/step - loss: 0.8336 - accuracy: 0.7220 - val_loss: 0.4239 - val_accuracy: 0.9000 - lr: 1.2500e-04
# Epoch 54/100
# 50/50 [==============================] - ETA: 0s - loss: 0.8181 - accuracy: 0.7280
# Epoch 54: val_accuracy did not improve from 0.90000
# 50/50 [==============================] - 15s 308ms/step - loss: 0.8181 - accuracy: 0.7280 - val_loss: 0.9125 - val_accuracy: 0.6600 - lr: 1.2500e-04
# Epoch 55/100
# 50/50 [==============================] - ETA: 0s - loss: 0.8298 - accuracy: 0.7280
# Epoch 55: val_accuracy did not improve from 0.90000
# 50/50 [==============================] - 16s 311ms/step - loss: 0.8298 - accuracy: 0.7280 - val_loss: 0.5800 - val_accuracy: 0.8000 - lr: 1.2500e-04
# Epoch 56/100
# 50/50 [==============================] - ETA: 0s - loss: 0.8499 - accuracy: 0.6860
# Epoch 56: val_accuracy did not improve from 0.90000
# 50/50 [==============================] - 18s 354ms/step - loss: 0.8499 - accuracy: 0.6860 - val_loss: 0.6886 - val_accuracy: 0.7400 - lr: 1.2500e-04
# Epoch 57/100
# 50/50 [==============================] - ETA: 0s - loss: 0.7581 - accuracy: 0.7340
# Epoch 57: val_accuracy did not improve from 0.90000
# 50/50 [==============================] - 15s 311ms/step - loss: 0.7581 - accuracy: 0.7340 - val_loss: 0.4996 - val_accuracy: 0.8600 - lr: 1.2500e-04
# Epoch 58/100
# 50/50 [==============================] - ETA: 0s - loss: 0.8515 - accuracy: 0.6940
# Epoch 58: val_accuracy did not improve from 0.90000
#
# Epoch 58: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 50/50 [==============================] - 16s 316ms/step - loss: 0.8515 - accuracy: 0.6940 - val_loss: 0.5576 - val_accuracy: 0.8200 - lr: 1.2500e-04
# Epoch 59/100
# 50/50 [==============================] - ETA: 0s - loss: 0.7712 - accuracy: 0.7320
# Epoch 59: val_accuracy did not improve from 0.90000
# 50/50 [==============================] - 16s 314ms/step - loss: 0.7712 - accuracy: 0.7320 - val_loss: 0.7055 - val_accuracy: 0.7600 - lr: 6.2500e-05
# Epoch 60/100
# 50/50 [==============================] - ETA: 0s - loss: 0.8090 - accuracy: 0.7180
# Epoch 60: val_accuracy did not improve from 0.90000
# 50/50 [==============================] - 16s 315ms/step - loss: 0.8090 - accuracy: 0.7180 - val_loss: 0.6943 - val_accuracy: 0.7800 - lr: 6.2500e-05
# Epoch 61/100
# 50/50 [==============================] - ETA: 0s - loss: 0.8352 - accuracy: 0.7140
# Epoch 61: val_accuracy did not improve from 0.90000
# 50/50 [==============================] - 16s 312ms/step - loss: 0.8352 - accuracy: 0.7140 - val_loss: 0.7303 - val_accuracy: 0.7400 - lr: 6.2500e-05
# Epoch 62/100
# 50/50 [==============================] - ETA: 0s - loss: 0.7974 - accuracy: 0.7140
# Epoch 62: val_accuracy did not improve from 0.90000
# 50/50 [==============================] - 16s 311ms/step - loss: 0.7974 - accuracy: 0.7140 - val_loss: 0.5411 - val_accuracy: 0.8200 - lr: 6.2500e-05
# Epoch 63/100
# 50/50 [==============================] - ETA: 0s - loss: 0.8446 - accuracy: 0.6860
# Epoch 63: val_accuracy did not improve from 0.90000
#
# Epoch 63: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 50/50 [==============================] - 16s 313ms/step - loss: 0.8446 - accuracy: 0.6860 - val_loss: 0.5226 - val_accuracy: 0.8800 - lr: 6.2500e-05
# Epoch 64/100
# 50/50 [==============================] - ETA: 0s - loss: 0.8639 - accuracy: 0.6840
# Epoch 64: val_accuracy did not improve from 0.90000
# 50/50 [==============================] - 16s 315ms/step - loss: 0.8639 - accuracy: 0.6840 - val_loss: 0.6814 - val_accuracy: 0.7600 - lr: 3.1250e-05
# Epoch 65/100
# 50/50 [==============================] - ETA: 0s - loss: 0.8153 - accuracy: 0.7149
# Epoch 65: val_accuracy did not improve from 0.90000
# 50/50 [==============================] - 16s 313ms/step - loss: 0.8153 - accuracy: 0.7149 - val_loss: 0.6617 - val_accuracy: 0.8200 - lr: 3.1250e-05
# Epoch 66/100
# 50/50 [==============================] - ETA: 0s - loss: 0.7648 - accuracy: 0.7300
# Epoch 66: val_accuracy did not improve from 0.90000
# 50/50 [==============================] - 16s 323ms/step - loss: 0.7648 - accuracy: 0.7300 - val_loss: 0.5713 - val_accuracy: 0.8200 - lr: 3.1250e-05
# Epoch 67/100
# 50/50 [==============================] - ETA: 0s - loss: 0.7711 - accuracy: 0.7340
# Epoch 67: val_accuracy did not improve from 0.90000
# 50/50 [==============================] - 16s 321ms/step - loss: 0.7711 - accuracy: 0.7340 - val_loss: 0.6152 - val_accuracy: 0.8000 - lr: 3.1250e-05
# Epoch 68/100
# 50/50 [==============================] - ETA: 0s - loss: 0.8657 - accuracy: 0.7028
# Epoch 68: val_accuracy did not improve from 0.90000
#
# Epoch 68: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 50/50 [==============================] - 16s 314ms/step - loss: 0.8657 - accuracy: 0.7028 - val_loss: 0.5249 - val_accuracy: 0.8200 - lr: 3.1250e-05
# Epoch 69/100
# 50/50 [==============================] - ETA: 0s - loss: 0.7979 - accuracy: 0.7240
# Epoch 69: val_accuracy did not improve from 0.90000
# 50/50 [==============================] - 16s 313ms/step - loss: 0.7979 - accuracy: 0.7240 - val_loss: 0.6141 - val_accuracy: 0.8400 - lr: 1.5625e-05
# Epoch 70/100
# 50/50 [==============================] - ETA: 0s - loss: 0.7878 - accuracy: 0.7260
# Epoch 70: val_accuracy did not improve from 0.90000
# 50/50 [==============================] - 16s 314ms/step - loss: 0.7878 - accuracy: 0.7260 - val_loss: 0.4658 - val_accuracy: 0.8400 - lr: 1.5625e-05
# Epoch 71/100
# 50/50 [==============================] - ETA: 0s - loss: 0.7804 - accuracy: 0.7340
# Epoch 71: val_accuracy did not improve from 0.90000
# 50/50 [==============================] - 16s 314ms/step - loss: 0.7804 - accuracy: 0.7340 - val_loss: 0.5241 - val_accuracy: 0.8400 - lr: 1.5625e-05
# Epoch 72/100
# 50/50 [==============================] - ETA: 0s - loss: 0.8410 - accuracy: 0.7169
# Epoch 72: val_accuracy did not improve from 0.90000
# 50/50 [==============================] - 17s 347ms/step - loss: 0.8410 - accuracy: 0.7169 - val_loss: 0.8443 - val_accuracy: 0.6800 - lr: 1.5625e-05
# Epoch 73/100
# 50/50 [==============================] - ETA: 0s - loss: 0.7974 - accuracy: 0.7120
# Epoch 73: val_accuracy did not improve from 0.90000
#
# Epoch 73: ReduceLROnPlateau reducing learning rate to 1e-05.
# 50/50 [==============================] - 16s 317ms/step - loss: 0.7974 - accuracy: 0.7120 - val_loss: 0.6106 - val_accuracy: 0.8200 - lr: 1.5625e-05
# Epoch 73: early stopping

# %%
predictions=network.predict(test_datatset)
predictions = np.argmax(predictions, axis=1)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(test_datatset.classes, predictions)
# Out:
# 0.8058739255014327

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(test_datatset.classes, predictions)
sns.heatmap(cm, annot=True);

# %%
from sklearn.metrics import classification_report
print(classification_report(test_datatset.classes, predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.91      0.94      0.93       198
#            1       0.98      0.99      0.99       200
#            2       0.68      0.71      0.70       200
#            3       0.69      0.52      0.59       199
#            4       0.79      0.96      0.87       200
#            5       0.77      0.66      0.71       199
#            6       0.79      0.85      0.82       200
#
#     accuracy                           0.81      1396
#    macro avg       0.80      0.81      0.80      1396
# weighted avg       0.80      0.81      0.80      1396

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
from tensorflow.keras.models import load_model
model = load_model('/content/best_model8.h5')

# %%
model.evaluate(test_datatset)
# Out:
# 1396/1396 [==============================] - 16s 11ms/step - loss: 0.6302 - accuracy: 0.7858
# [0.6301770210266113, 0.7858166098594666]

# %%
pred = model.predict(test_datatset)
pred = np.argmax(pred, axis=1)
cm = confusion_matrix(test_datatset.classes, pred)
sns.heatmap(cm, annot=True);

# %%
print(classification_report(test_datatset.classes, pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.89      0.94      0.91       198
#            1       0.98      0.99      0.99       200
#            2       0.67      0.72      0.69       200
#            3       0.72      0.39      0.50       199
#            4       0.75      0.97      0.85       200
#            5       0.70      0.68      0.69       199
#            6       0.77      0.81      0.79       200
#
#     accuracy                           0.79      1396
#    macro avg       0.78      0.79      0.77      1396
# weighted avg       0.78      0.79      0.77      1396

# %%
network.save('network.h5')

# %%
net = load_model('/content/network.h5')

# %%
net.evaluate(test_datatset)
# Out:
# 1396/1396 [==============================] - 16s 11ms/step - loss: 0.5891 - accuracy: 0.8059
# [0.5891348123550415, 0.8058739304542542]

# %%
pre = net.predict(test_datatset)
pre = np.argmax(pre, axis=1)
cm = confusion_matrix(test_datatset.classes, pre)
sns.heatmap(cm, annot=True);

# %%
print(classification_report(test_datatset.classes, pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.89      0.94      0.91       198
#            1       0.98      0.99      0.99       200
#            2       0.67      0.72      0.69       200
#            3       0.72      0.39      0.50       199
#            4       0.75      0.97      0.85       200
#            5       0.70      0.68      0.69       199
#            6       0.77      0.81      0.79       200
#
#     accuracy                           0.79      1396
#    macro avg       0.78      0.79      0.77      1396
# weighted avg       0.78      0.79      0.77      1396
