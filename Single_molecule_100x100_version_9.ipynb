# %% [markdown]
# <a href="https://colab.research.google.com/github/SebastianKosmider/Praktyki/blob/main/Single_molecule_100x100_version_9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install h5py
# !pip install typing-extensions
# !pip install wheel
# Out:
# Requirement already satisfied: h5py in /usr/local/lib/python3.10/dist-packages (3.9.0)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.10/dist-packages (from h5py) (1.23.5)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (4.7.1)
# Requirement already satisfied: wheel in /usr/local/lib/python3.10/dist-packages (0.41.1)

# %%
# !pip install tensorflow==2.8
# Out:
# Collecting tensorflow==2.8
#   Downloading tensorflow-2.8.0-cp310-cp310-manylinux2010_x86_64.whl (497.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 497.6/497.6 MB 1.2 MB/s eta 0:00:00
# Requirement already satisfied: absl-py>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8) (1.6.3)
# Requirement already satisfied: flatbuffers>=1.12 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8) (23.5.26)
# Requirement already satisfied: gast>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8) (0.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8) (3.9.0)
# Collecting keras-preprocessing>=1.1.1 (from tensorflow==2.8)
#   Downloading Keras_Preprocessing-1.1.2-py2.py3-none-any.whl (42 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.6/42.6 kB 4.1 MB/s eta 0:00:00
# Requirement already satisfied: libclang>=9.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8) (16.0.6)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8) (1.23.5)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8) (3.3.0)
# Requirement already satisfied: protobuf>=3.9.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8) (3.20.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8) (67.7.2)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8) (2.3.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8) (4.7.1)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8) (1.14.1)
# Collecting tensorboard<2.9,>=2.8 (from tensorflow==2.8)
#   Downloading tensorboard-2.8.0-py3-none-any.whl (5.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.8/5.8 MB 40.9 MB/s eta 0:00:00
# Collecting tf-estimator-nightly==2.8.0.dev2021122109 (from tensorflow==2.8)
#   Downloading tf_estimator_nightly-2.8.0.dev2021122109-py2.py3-none-any.whl (462 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 462.5/462.5 kB 16.6 MB/s eta 0:00:00
# Collecting keras<2.9,>=2.8.0rc0 (from tensorflow==2.8)
#   Downloading keras-2.8.0-py2.py3-none-any.whl (1.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 43.0 MB/s eta 0:00:00
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8) (0.33.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8) (1.57.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow==2.8) (0.41.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.9,>=2.8->tensorflow==2.8) (2.17.3)
# Collecting google-auth-oauthlib<0.5,>=0.4.1 (from tensorboard<2.9,>=2.8->tensorflow==2.8)
#   Downloading google_auth_oauthlib-0.4.6-py2.py3-none-any.whl (18 kB)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.9,>=2.8->tensorflow==2.8) (3.4.4)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.9,>=2.8->tensorflow==2.8) (2.31.0)
# Collecting tensorboard-data-server<0.7.0,>=0.6.0 (from tensorboard<2.9,>=2.8->tensorflow==2.8)
#   Downloading tensorboard_data_server-0.6.1-py3-none-manylinux2010_x86_64.whl (4.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 30.5 MB/s eta 0:00:00
# Collecting tensorboard-plugin-wit>=1.6.0 (from tensorboard<2.9,>=2.8->tensorflow==2.8)
#   Downloading tensorboard_plugin_wit-1.8.1-py3-none-any.whl (781 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 781.3/781.3 kB 30.5 MB/s eta 0:00:00
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.9,>=2.8->tensorflow==2.8) (2.3.6)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow==2.8) (5.3.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow==2.8) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow==2.8) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow==2.8) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow==2.8) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow==2.8) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow==2.8) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow==2.8) (2023.7.22)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=0.11.15->tensorboard<2.9,>=2.8->tensorflow==2.8) (2.1.3)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow==2.8) (0.5.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow==2.8) (3.2.2)
# Installing collected packages: tf-estimator-nightly, tensorboard-plugin-wit, keras, tensorboard-data-server, keras-preprocessing, google-auth-oauthlib, tensorboard, tensorflow
#   Attempting uninstall: keras
#     Found existing installation: keras 2.12.0
#     Uninstalling keras-2.12.0:
#       Successfully uninstalled keras-2.12.0
#   Attempting uninstall: tensorboard-data-server
#     Found existing installation: tensorboard-data-server 0.7.1
#     Uninstalling tensorboard-data-server-0.7.1:
#       Successfully uninstalled tensorboard-data-server-0.7.1
#   Attempting uninstall: google-auth-oauthlib
#     Found existing installation: google-auth-oauthlib 1.0.0
#     Uninstalling google-auth-oauthlib-1.0.0:
#       Successfully uninstalled google-auth-oauthlib-1.0.0
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.12.3
#     Uninstalling tensorboard-2.12.3:
#       Successfully uninstalled tensorboard-2.12.3
#   Attempting uninstall: tensorflow
#     Found existing installation: tensorflow 2.12.0
#     Uninstalling tensorflow-2.12.0:
#       Successfully uninstalled tensorflow-2.12.0
# Successfully installed google-auth-oauthlib-0.4.6 keras-2.8.0 keras-preprocessing-1.1.2 tensorboard-2.8.0 tensorboard-data-server-0.6.1 tensorboard-plugin-wit-1.8.1 tensorflow-2.8.0 tf-estimator-nightly-2.8.0.dev2021122109

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import zipfile
import numpy as np
import cv2
from google.colab.patches import cv2_imshow
import tensorflow as tf
from tensorflow.keras.callbacks import ReduceLROnPlateau
from tensorflow.keras import regularizers
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPool2D, Flatten, Dense, BatchNormalization, Dropout
from tensorflow.keras.preprocessing.image import ImageDataGenerator
tf.__version__
# Out:
# '2.8.0'

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
path = '/content/drive/MyDrive/praktyki/rawDataSingleMolecule/gotowe.zip'
zip_object = zipfile.ZipFile(file=path, mode='r')
zip_object.extractall('./')
zip_object.close()

# %%
training_generator = ImageDataGenerator(rescale=1./255,
                                        horizontal_flip=True,
                                        vertical_flip=True)

# %%
train_dataset = training_generator.flow_from_directory('/content/gotowe/train_set',
                                                       target_size = (100, 100),
                                                       batch_size = 10,
                                                       color_mode='rgb',
                                                       class_mode = 'categorical',
                                                       shuffle = True)
# Out:
# Found 11158 images belonging to 7 classes.

# %%
train_dataset.classes
# Out:
# array([0, 0, 0, ..., 6, 6, 6], dtype=int32)

# %%
train_dataset.class_indices
# Out:
# {'nematyk': 0,
#  'smektyk_C': 1,
#  'smektyk_F': 2,
#  'smektyk_GMosaic': 3,
#  'smektyk_GSchliren': 4,
#  'smektyk_H': 5,
#  'smektyk_I': 6}

# %%
test_generator = ImageDataGenerator(rescale=1./255)
val_generator = ImageDataGenerator(rescale=1./255)

# %%
validation_dataset = val_generator.flow_from_directory('/content/gotowe/val_set',
                                                        target_size=(100, 100),
                                                        batch_size=1,
                                                        class_mode='categorical',
                                                        color_mode='rgb',
                                                        shuffle=True) # set as validation data
# Out:
# Found 1395 images belonging to 7 classes.

# %%
L2 = 0.00001

# %%
test_datatset = test_generator.flow_from_directory('/content/gotowe/test_set',
                                                   target_size = (100, 100),
                                                   batch_size = 1,
                                                   color_mode='rgb',
                                                   class_mode = 'categorical',
                                                   shuffle = False)
# Out:
# Found 1396 images belonging to 7 classes.

# %%
initializer1 = tf.keras.initializers.HeNormal()
initializer2 = tf.keras.initializers.GlorotUniform()

# %%
network = Sequential()
network.add(Conv2D(filters=16, kernel_size=(3,3), activation = 'relu', input_shape = (100,100,3), kernel_initializer=initializer1))
network.add(Conv2D(filters=16, kernel_size=(3,3), activation = 'relu', padding='same', kernel_initializer=initializer1))
network.add(Conv2D(filters=16, kernel_size=(3,3), activation = 'relu', padding='same', kernel_initializer=initializer1))
network.add(BatchNormalization())
network.add(MaxPool2D(pool_size=(2,2)))

network.add(Conv2D(filters=32, kernel_size=(3,3), activation = 'relu', padding='same', kernel_initializer=initializer1))
network.add(Conv2D(filters=32, kernel_size=(3,3), activation = 'relu', padding='same', kernel_initializer=initializer1))
network.add(Conv2D(filters=32, kernel_size=(3,3), activation = 'relu', padding='same', kernel_initializer=initializer1))
network.add(BatchNormalization())
network.add(MaxPool2D(pool_size=(2,2)))

network.add(Conv2D(filters=64, kernel_size=(3,3), activation = 'relu', padding='same', kernel_initializer=initializer1))
network.add(Conv2D(filters=64, kernel_size=(3,3), activation = 'relu', padding='same', kernel_initializer=initializer1))
network.add(BatchNormalization())
network.add(MaxPool2D(pool_size=(2,2)))

network.add(Conv2D(filters=128, kernel_size=(3,3), activation = 'relu', padding='same', kernel_initializer=initializer1))
network.add(Conv2D(filters=128, kernel_size=(3,3), activation = 'relu', padding='same', kernel_initializer=initializer1))
network.add(Conv2D(filters=128, kernel_size=(3,3), activation = 'relu', padding='same', kernel_initializer=initializer1))
network.add(BatchNormalization())
network.add(MaxPool2D(pool_size=(2,2)))

network.add(Conv2D(filters=256, kernel_size=(1,1), activation = 'relu', padding='same', kernel_initializer=initializer1))
network.add(BatchNormalization())
network.add(MaxPool2D(pool_size=(2,2)))

network.add(Conv2D(filters=512, kernel_size=(1,1), activation = 'relu', padding='same', kernel_initializer=initializer1))
network.add(Conv2D(filters=512, kernel_size=(1,1), activation = 'relu', padding='same', kernel_initializer=initializer1))
network.add(BatchNormalization())
network.add(MaxPool2D(pool_size=(2,2)))

network.add(Flatten())

network.add(Dropout(0.23))

network.add(Dense(units = 512, activation = 'relu', kernel_initializer=initializer1))
network.add(BatchNormalization())
network.add(Dense(units = 512, activation = 'relu', kernel_initializer=initializer1))
network.add(BatchNormalization())
network.add(Dense(units = 128, activation = 'relu', kernel_initializer=initializer1))
network.add(BatchNormalization())
network.add(Dense(units = 128, activation = 'relu', kernel_initializer=initializer1))
network.add(BatchNormalization())
network.add(Dense(units = 64, activation = 'relu', kernel_initializer=initializer1))
network.add(BatchNormalization())
network.add(Dense(units = 32, activation = 'relu', kernel_initializer=initializer1))
network.add(BatchNormalization())
network.add(Dense(units = 32, activation = 'relu', kernel_initializer=initializer1))
network.add(BatchNormalization())
network.add(Dense(units = 16, activation = 'relu', kernel_initializer=initializer1, kernel_regularizer=tf.keras.regularizers.L1L2()))
network.add(BatchNormalization())
network.add(Dense(units = 7, activation = 'softmax', kernel_initializer=initializer2))
network.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 98, 98, 16)        448
#
#  conv2d_1 (Conv2D)           (None, 98, 98, 16)        2320
#
#  conv2d_2 (Conv2D)           (None, 98, 98, 16)        2320
#
#  batch_normalization (BatchN  (None, 98, 98, 16)       64
#  ormalization)
#
#  max_pooling2d (MaxPooling2D  (None, 49, 49, 16)       0
#  )
#
#  conv2d_3 (Conv2D)           (None, 49, 49, 32)        4640
#
#  conv2d_4 (Conv2D)           (None, 49, 49, 32)        9248
#
#  conv2d_5 (Conv2D)           (None, 49, 49, 32)        9248
#
#  batch_normalization_1 (Batc  (None, 49, 49, 32)       128
#  hNormalization)
#
#  max_pooling2d_1 (MaxPooling  (None, 24, 24, 32)       0
#  2D)
#
#  conv2d_6 (Conv2D)           (None, 24, 24, 64)        18496
#
#  conv2d_7 (Conv2D)           (None, 24, 24, 64)        36928
#
#  batch_normalization_2 (Batc  (None, 24, 24, 64)       256
#  hNormalization)
#
#  max_pooling2d_2 (MaxPooling  (None, 12, 12, 64)       0
#  2D)
#
#  conv2d_8 (Conv2D)           (None, 12, 12, 128)       73856
#
#  conv2d_9 (Conv2D)           (None, 12, 12, 128)       147584
#
#  conv2d_10 (Conv2D)          (None, 12, 12, 128)       147584
#
#  batch_normalization_3 (Batc  (None, 12, 12, 128)      512
#  hNormalization)
#
#  max_pooling2d_3 (MaxPooling  (None, 6, 6, 128)        0
#  2D)
#
#  conv2d_11 (Conv2D)          (None, 6, 6, 256)         33024
#
#  batch_normalization_4 (Batc  (None, 6, 6, 256)        1024
#  hNormalization)
#
#  max_pooling2d_4 (MaxPooling  (None, 3, 3, 256)        0
#  2D)
#
#  conv2d_12 (Conv2D)          (None, 3, 3, 512)         131584
#
#  conv2d_13 (Conv2D)          (None, 3, 3, 512)         262656
#
#  batch_normalization_5 (Batc  (None, 3, 3, 512)        2048
#  hNormalization)
#
#  max_pooling2d_5 (MaxPooling  (None, 1, 1, 512)        0
#  2D)
#
#  flatten (Flatten)           (None, 512)               0
#
#  dropout (Dropout)           (None, 512)               0
#
#  dense (Dense)               (None, 512)               262656
#
#  batch_normalization_6 (Batc  (None, 512)              2048
#  hNormalization)
#
#  dense_1 (Dense)             (None, 512)               262656
#
#  batch_normalization_7 (Batc  (None, 512)              2048
#  hNormalization)
#
#  dense_2 (Dense)             (None, 128)               65664
#
#  batch_normalization_8 (Batc  (None, 128)              512
#  hNormalization)
#
#  dense_3 (Dense)             (None, 128)               16512
#
#  batch_normalization_9 (Batc  (None, 128)              512
#  hNormalization)
#
#  dense_4 (Dense)             (None, 64)                8256
#
#  batch_normalization_10 (Bat  (None, 64)               256
#  chNormalization)
#
#  dense_5 (Dense)             (None, 32)                2080
#
#  batch_normalization_11 (Bat  (None, 32)               128
#  chNormalization)
#
#  dense_6 (Dense)             (None, 32)                1056
#
#  batch_normalization_12 (Bat  (None, 32)               128
#  chNormalization)
#
#  dense_7 (Dense)             (None, 16)                528
#
#  batch_normalization_13 (Bat  (None, 16)               64
#  chNormalization)
#
#  dense_8 (Dense)             (None, 7)                 119
#
# =================================================================
# Total params: 1,509,191
# Trainable params: 1,504,327
# Non-trainable params: 4,864
# _________________________________________________________________

# %%
from tensorflow.keras.optimizers import Adam
#opt = Adam(lr=0.005)
opt = Adam()
network.compile(optimizer='Adam', loss='categorical_crossentropy', metrics = ['accuracy'])

# %%
es = EarlyStopping(monitor = 'val_accuracy', min_delta = 0.001, patience = 20, verbose =1)
model_cp = ModelCheckpoint(filepath = 'best_model9.h5', monitor = 'val_accuracy', save_best_only = True, verbose = 1)
learning_rate_reduction = ReduceLROnPlateau(monitor='val_accuracy', patience = 5, verbose=1, factor=0.5, min_lr=0.00001)

# %%
history = network.fit_generator(train_dataset,
                                steps_per_epoch = 50,
                                validation_data = validation_dataset,
                                validation_steps = 50,
                                epochs=100,
                                callbacks=[es, model_cp, learning_rate_reduction])
# Out:
# Epoch 1/100
# <ipython-input-18-d45876fe1552>:1: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history = network.fit_generator(train_dataset,
# 50/50 [==============================] - ETA: 0s - loss: 2.6192 - accuracy: 0.1520
# Epoch 1: val_accuracy improved from -inf to 0.16000, saving model to best_model9.h5
# 50/50 [==============================] - 41s 729ms/step - loss: 2.6192 - accuracy: 0.1520 - val_loss: 1.8901 - val_accuracy: 0.1600 - lr: 0.0010
# Epoch 2/100
# 50/50 [==============================] - ETA: 0s - loss: 2.3140 - accuracy: 0.1780
# Epoch 2: val_accuracy improved from 0.16000 to 0.34000, saving model to best_model9.h5
# 50/50 [==============================] - 35s 696ms/step - loss: 2.3140 - accuracy: 0.1780 - val_loss: 1.8778 - val_accuracy: 0.3400 - lr: 0.0010
# Epoch 3/100
# 50/50 [==============================] - ETA: 0s - loss: 2.0777 - accuracy: 0.2120
# Epoch 3: val_accuracy did not improve from 0.34000
# 50/50 [==============================] - 34s 687ms/step - loss: 2.0777 - accuracy: 0.2120 - val_loss: 2.3114 - val_accuracy: 0.2200 - lr: 0.0010
# Epoch 4/100
# 50/50 [==============================] - ETA: 0s - loss: 1.9350 - accuracy: 0.2300
# Epoch 4: val_accuracy did not improve from 0.34000
# 50/50 [==============================] - 34s 663ms/step - loss: 1.9350 - accuracy: 0.2300 - val_loss: 2.0046 - val_accuracy: 0.2200 - lr: 0.0010
# Epoch 5/100
# 50/50 [==============================] - ETA: 0s - loss: 1.8640 - accuracy: 0.2440
# Epoch 5: val_accuracy did not improve from 0.34000
# 50/50 [==============================] - 34s 687ms/step - loss: 1.8640 - accuracy: 0.2440 - val_loss: 2.2994 - val_accuracy: 0.1800 - lr: 0.0010
# Epoch 6/100
# 50/50 [==============================] - ETA: 0s - loss: 1.7215 - accuracy: 0.3420
# Epoch 6: val_accuracy did not improve from 0.34000
# 50/50 [==============================] - 34s 682ms/step - loss: 1.7215 - accuracy: 0.3420 - val_loss: 1.9062 - val_accuracy: 0.3000 - lr: 0.0010
# Epoch 7/100
# 50/50 [==============================] - ETA: 0s - loss: 1.7025 - accuracy: 0.3340
# Epoch 7: val_accuracy did not improve from 0.34000
#
# Epoch 7: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 50/50 [==============================] - 34s 678ms/step - loss: 1.7025 - accuracy: 0.3340 - val_loss: 1.8140 - val_accuracy: 0.3400 - lr: 0.0010
# Epoch 8/100
# 50/50 [==============================] - ETA: 0s - loss: 1.6946 - accuracy: 0.3080
# Epoch 8: val_accuracy did not improve from 0.34000
# 50/50 [==============================] - 36s 733ms/step - loss: 1.6946 - accuracy: 0.3080 - val_loss: 2.1642 - val_accuracy: 0.2000 - lr: 5.0000e-04
# Epoch 9/100
# 50/50 [==============================] - ETA: 0s - loss: 1.6734 - accuracy: 0.3460
# Epoch 9: val_accuracy improved from 0.34000 to 0.38000, saving model to best_model9.h5
# 50/50 [==============================] - 38s 759ms/step - loss: 1.6734 - accuracy: 0.3460 - val_loss: 1.8056 - val_accuracy: 0.3800 - lr: 5.0000e-04
# Epoch 10/100
# 50/50 [==============================] - ETA: 0s - loss: 1.6387 - accuracy: 0.3640
# Epoch 10: val_accuracy did not improve from 0.38000
# 50/50 [==============================] - 34s 682ms/step - loss: 1.6387 - accuracy: 0.3640 - val_loss: 1.8269 - val_accuracy: 0.2200 - lr: 5.0000e-04
# Epoch 11/100
# 50/50 [==============================] - ETA: 0s - loss: 1.6627 - accuracy: 0.4020
# Epoch 11: val_accuracy did not improve from 0.38000
# 50/50 [==============================] - 34s 690ms/step - loss: 1.6627 - accuracy: 0.4020 - val_loss: 1.7919 - val_accuracy: 0.2800 - lr: 5.0000e-04
# Epoch 12/100
# 50/50 [==============================] - ETA: 0s - loss: 1.6106 - accuracy: 0.3960
# Epoch 12: val_accuracy did not improve from 0.38000
# 50/50 [==============================] - 34s 691ms/step - loss: 1.6106 - accuracy: 0.3960 - val_loss: 1.5501 - val_accuracy: 0.3800 - lr: 5.0000e-04
# Epoch 13/100
# 50/50 [==============================] - ETA: 0s - loss: 1.6329 - accuracy: 0.3920
# Epoch 13: val_accuracy improved from 0.38000 to 0.40000, saving model to best_model9.h5
# 50/50 [==============================] - 34s 684ms/step - loss: 1.6329 - accuracy: 0.3920 - val_loss: 1.6085 - val_accuracy: 0.4000 - lr: 5.0000e-04
# Epoch 14/100
# 50/50 [==============================] - ETA: 0s - loss: 1.5568 - accuracy: 0.4200
# Epoch 14: val_accuracy improved from 0.40000 to 0.48000, saving model to best_model9.h5
# 50/50 [==============================] - 33s 668ms/step - loss: 1.5568 - accuracy: 0.4200 - val_loss: 1.4722 - val_accuracy: 0.4800 - lr: 5.0000e-04
# Epoch 15/100
# 50/50 [==============================] - ETA: 0s - loss: 1.6098 - accuracy: 0.3960
# Epoch 15: val_accuracy improved from 0.48000 to 0.68000, saving model to best_model9.h5
# 50/50 [==============================] - 35s 696ms/step - loss: 1.6098 - accuracy: 0.3960 - val_loss: 1.1536 - val_accuracy: 0.6800 - lr: 5.0000e-04
# Epoch 16/100
# 50/50 [==============================] - ETA: 0s - loss: 1.6219 - accuracy: 0.3920
# Epoch 16: val_accuracy did not improve from 0.68000
# 50/50 [==============================] - 34s 684ms/step - loss: 1.6219 - accuracy: 0.3920 - val_loss: 1.2718 - val_accuracy: 0.5800 - lr: 5.0000e-04
# Epoch 17/100
# 50/50 [==============================] - ETA: 0s - loss: 1.5865 - accuracy: 0.3980
# Epoch 17: val_accuracy did not improve from 0.68000
# 50/50 [==============================] - 38s 759ms/step - loss: 1.5865 - accuracy: 0.3980 - val_loss: 1.5158 - val_accuracy: 0.4800 - lr: 5.0000e-04
# Epoch 18/100
# 50/50 [==============================] - ETA: 0s - loss: 1.5531 - accuracy: 0.4240
# Epoch 18: val_accuracy did not improve from 0.68000
# 50/50 [==============================] - 34s 686ms/step - loss: 1.5531 - accuracy: 0.4240 - val_loss: 1.3389 - val_accuracy: 0.5400 - lr: 5.0000e-04
# Epoch 19/100
# 50/50 [==============================] - ETA: 0s - loss: 1.5139 - accuracy: 0.4380
# Epoch 19: val_accuracy did not improve from 0.68000
# 50/50 [==============================] - 34s 680ms/step - loss: 1.5139 - accuracy: 0.4380 - val_loss: 1.5235 - val_accuracy: 0.3800 - lr: 5.0000e-04
# Epoch 20/100
# 50/50 [==============================] - ETA: 0s - loss: 1.5077 - accuracy: 0.4480
# Epoch 20: val_accuracy did not improve from 0.68000
#
# Epoch 20: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 50/50 [==============================] - 34s 662ms/step - loss: 1.5077 - accuracy: 0.4480 - val_loss: 1.4705 - val_accuracy: 0.5400 - lr: 5.0000e-04
# Epoch 21/100
# 50/50 [==============================] - ETA: 0s - loss: 1.5055 - accuracy: 0.4320
# Epoch 21: val_accuracy did not improve from 0.68000
# 50/50 [==============================] - 34s 686ms/step - loss: 1.5055 - accuracy: 0.4320 - val_loss: 1.5698 - val_accuracy: 0.3800 - lr: 2.5000e-04
# Epoch 22/100
# 50/50 [==============================] - ETA: 0s - loss: 1.5728 - accuracy: 0.4220
# Epoch 22: val_accuracy did not improve from 0.68000
# 50/50 [==============================] - 37s 747ms/step - loss: 1.5728 - accuracy: 0.4220 - val_loss: 1.4347 - val_accuracy: 0.4600 - lr: 2.5000e-04
# Epoch 23/100
# 50/50 [==============================] - ETA: 0s - loss: 1.4720 - accuracy: 0.4860
# Epoch 23: val_accuracy did not improve from 0.68000
# 50/50 [==============================] - 34s 692ms/step - loss: 1.4720 - accuracy: 0.4860 - val_loss: 1.3178 - val_accuracy: 0.4800 - lr: 2.5000e-04
# Epoch 24/100
# 50/50 [==============================] - ETA: 0s - loss: 1.4722 - accuracy: 0.4500
# Epoch 24: val_accuracy did not improve from 0.68000
# 50/50 [==============================] - 39s 777ms/step - loss: 1.4722 - accuracy: 0.4500 - val_loss: 1.2760 - val_accuracy: 0.5000 - lr: 2.5000e-04
# Epoch 25/100
# 50/50 [==============================] - ETA: 0s - loss: 1.4204 - accuracy: 0.4740
# Epoch 25: val_accuracy did not improve from 0.68000
#
# Epoch 25: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 50/50 [==============================] - 35s 705ms/step - loss: 1.4204 - accuracy: 0.4740 - val_loss: 1.0816 - val_accuracy: 0.6600 - lr: 2.5000e-04
# Epoch 26/100
# 50/50 [==============================] - ETA: 0s - loss: 1.5089 - accuracy: 0.4360
# Epoch 26: val_accuracy did not improve from 0.68000
# 50/50 [==============================] - 34s 679ms/step - loss: 1.5089 - accuracy: 0.4360 - val_loss: 1.2895 - val_accuracy: 0.5200 - lr: 1.2500e-04
# Epoch 27/100
# 50/50 [==============================] - ETA: 0s - loss: 1.4541 - accuracy: 0.4560
# Epoch 27: val_accuracy did not improve from 0.68000
# 50/50 [==============================] - 34s 687ms/step - loss: 1.4541 - accuracy: 0.4560 - val_loss: 1.1389 - val_accuracy: 0.6600 - lr: 1.2500e-04
# Epoch 28/100
# 50/50 [==============================] - ETA: 0s - loss: 1.5406 - accuracy: 0.4360
# Epoch 28: val_accuracy did not improve from 0.68000
# 50/50 [==============================] - 34s 690ms/step - loss: 1.5406 - accuracy: 0.4360 - val_loss: 1.3789 - val_accuracy: 0.5000 - lr: 1.2500e-04
# Epoch 29/100
# 50/50 [==============================] - ETA: 0s - loss: 1.4421 - accuracy: 0.4900
# Epoch 29: val_accuracy improved from 0.68000 to 0.72000, saving model to best_model9.h5
# 50/50 [==============================] - 34s 679ms/step - loss: 1.4421 - accuracy: 0.4900 - val_loss: 0.8622 - val_accuracy: 0.7200 - lr: 1.2500e-04
# Epoch 30/100
# 50/50 [==============================] - ETA: 0s - loss: 1.4363 - accuracy: 0.4720
# Epoch 30: val_accuracy did not improve from 0.72000
# 50/50 [==============================] - 35s 706ms/step - loss: 1.4363 - accuracy: 0.4720 - val_loss: 1.1223 - val_accuracy: 0.6200 - lr: 1.2500e-04
# Epoch 31/100
# 50/50 [==============================] - ETA: 0s - loss: 1.4308 - accuracy: 0.4860
# Epoch 31: val_accuracy did not improve from 0.72000
# 50/50 [==============================] - 39s 780ms/step - loss: 1.4308 - accuracy: 0.4860 - val_loss: 1.0645 - val_accuracy: 0.7000 - lr: 1.2500e-04
# Epoch 32/100
# 50/50 [==============================] - ETA: 0s - loss: 1.3649 - accuracy: 0.5000
# Epoch 32: val_accuracy did not improve from 0.72000
# 50/50 [==============================] - 34s 690ms/step - loss: 1.3649 - accuracy: 0.5000 - val_loss: 1.1885 - val_accuracy: 0.5200 - lr: 1.2500e-04
# Epoch 33/100
# 50/50 [==============================] - ETA: 0s - loss: 1.4118 - accuracy: 0.4740
# Epoch 33: val_accuracy did not improve from 0.72000
# 50/50 [==============================] - 35s 692ms/step - loss: 1.4118 - accuracy: 0.4740 - val_loss: 1.2514 - val_accuracy: 0.6000 - lr: 1.2500e-04
# Epoch 34/100
# 50/50 [==============================] - ETA: 0s - loss: 1.4075 - accuracy: 0.4860
# Epoch 34: val_accuracy did not improve from 0.72000
#
# Epoch 34: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 50/50 [==============================] - 34s 694ms/step - loss: 1.4075 - accuracy: 0.4860 - val_loss: 1.1424 - val_accuracy: 0.6200 - lr: 1.2500e-04
# Epoch 35/100
# 50/50 [==============================] - ETA: 0s - loss: 1.4548 - accuracy: 0.4500
# Epoch 35: val_accuracy did not improve from 0.72000
# 50/50 [==============================] - 35s 699ms/step - loss: 1.4548 - accuracy: 0.4500 - val_loss: 1.2367 - val_accuracy: 0.5200 - lr: 6.2500e-05
# Epoch 36/100
# 50/50 [==============================] - ETA: 0s - loss: 1.3808 - accuracy: 0.4760
# Epoch 36: val_accuracy did not improve from 0.72000
# 50/50 [==============================] - 35s 692ms/step - loss: 1.3808 - accuracy: 0.4760 - val_loss: 1.2678 - val_accuracy: 0.6400 - lr: 6.2500e-05
# Epoch 37/100
# 50/50 [==============================] - ETA: 0s - loss: 1.4004 - accuracy: 0.4780
# Epoch 37: val_accuracy did not improve from 0.72000
# 50/50 [==============================] - 35s 697ms/step - loss: 1.4004 - accuracy: 0.4780 - val_loss: 1.4012 - val_accuracy: 0.5400 - lr: 6.2500e-05
# Epoch 38/100
# 50/50 [==============================] - ETA: 0s - loss: 1.3742 - accuracy: 0.4980
# Epoch 38: val_accuracy did not improve from 0.72000
# 50/50 [==============================] - 35s 694ms/step - loss: 1.3742 - accuracy: 0.4980 - val_loss: 1.4584 - val_accuracy: 0.4600 - lr: 6.2500e-05
# Epoch 39/100
# 50/50 [==============================] - ETA: 0s - loss: 1.3610 - accuracy: 0.4960
# Epoch 39: val_accuracy did not improve from 0.72000
#
# Epoch 39: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 50/50 [==============================] - 38s 771ms/step - loss: 1.3610 - accuracy: 0.4960 - val_loss: 1.0910 - val_accuracy: 0.6600 - lr: 6.2500e-05
# Epoch 40/100
# 50/50 [==============================] - ETA: 0s - loss: 1.4056 - accuracy: 0.4560
# Epoch 40: val_accuracy did not improve from 0.72000
# 50/50 [==============================] - 35s 708ms/step - loss: 1.4056 - accuracy: 0.4560 - val_loss: 1.2692 - val_accuracy: 0.5200 - lr: 3.1250e-05
# Epoch 41/100
# 50/50 [==============================] - ETA: 0s - loss: 1.4310 - accuracy: 0.4540
# Epoch 41: val_accuracy did not improve from 0.72000
# 50/50 [==============================] - 38s 764ms/step - loss: 1.4310 - accuracy: 0.4540 - val_loss: 1.0498 - val_accuracy: 0.6600 - lr: 3.1250e-05
# Epoch 42/100
# 50/50 [==============================] - ETA: 0s - loss: 1.4452 - accuracy: 0.4580
# Epoch 42: val_accuracy did not improve from 0.72000
# 50/50 [==============================] - 34s 690ms/step - loss: 1.4452 - accuracy: 0.4580 - val_loss: 0.9775 - val_accuracy: 0.7200 - lr: 3.1250e-05
# Epoch 43/100
# 50/50 [==============================] - ETA: 0s - loss: 1.3715 - accuracy: 0.4780
# Epoch 43: val_accuracy did not improve from 0.72000
# 50/50 [==============================] - 33s 669ms/step - loss: 1.3715 - accuracy: 0.4780 - val_loss: 1.0511 - val_accuracy: 0.7000 - lr: 3.1250e-05
# Epoch 44/100
# 50/50 [==============================] - ETA: 0s - loss: 1.3350 - accuracy: 0.5000
# Epoch 44: val_accuracy did not improve from 0.72000
#
# Epoch 44: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 50/50 [==============================] - 34s 678ms/step - loss: 1.3350 - accuracy: 0.5000 - val_loss: 1.2561 - val_accuracy: 0.6000 - lr: 3.1250e-05
# Epoch 45/100
# 50/50 [==============================] - ETA: 0s - loss: 1.3251 - accuracy: 0.5280
# Epoch 45: val_accuracy did not improve from 0.72000
# 50/50 [==============================] - 35s 698ms/step - loss: 1.3251 - accuracy: 0.5280 - val_loss: 1.0169 - val_accuracy: 0.7000 - lr: 1.5625e-05
# Epoch 46/100
# 50/50 [==============================] - ETA: 0s - loss: 1.3926 - accuracy: 0.5000
# Epoch 46: val_accuracy did not improve from 0.72000
# 50/50 [==============================] - 38s 767ms/step - loss: 1.3926 - accuracy: 0.5000 - val_loss: 0.9349 - val_accuracy: 0.7000 - lr: 1.5625e-05
# Epoch 47/100
# 50/50 [==============================] - ETA: 0s - loss: 1.3700 - accuracy: 0.4720
# Epoch 47: val_accuracy did not improve from 0.72000
# 50/50 [==============================] - 34s 670ms/step - loss: 1.3700 - accuracy: 0.4720 - val_loss: 1.1998 - val_accuracy: 0.5800 - lr: 1.5625e-05
# Epoch 48/100
# 50/50 [==============================] - ETA: 0s - loss: 1.4438 - accuracy: 0.4520
# Epoch 48: val_accuracy did not improve from 0.72000
# 50/50 [==============================] - 34s 692ms/step - loss: 1.4438 - accuracy: 0.4520 - val_loss: 1.1679 - val_accuracy: 0.6200 - lr: 1.5625e-05
# Epoch 49/100
# 50/50 [==============================] - ETA: 0s - loss: 1.3268 - accuracy: 0.5000
# Epoch 49: val_accuracy did not improve from 0.72000
#
# Epoch 49: ReduceLROnPlateau reducing learning rate to 1e-05.
# 50/50 [==============================] - 35s 695ms/step - loss: 1.3268 - accuracy: 0.5000 - val_loss: 1.2348 - val_accuracy: 0.6400 - lr: 1.5625e-05
# Epoch 49: early stopping

# %%
predictions=network.predict(test_datatset)
predictions = np.argmax(predictions, axis=1)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(test_datatset.classes, predictions)
# Out:
# 0.5974212034383954

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(test_datatset.classes, predictions)
sns.heatmap(cm, annot=True);

# %%
from sklearn.metrics import classification_report
print(classification_report(test_datatset.classes, predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.62      0.83      0.71       198
#            1       0.89      0.94      0.91       200
#            2       0.54      0.12      0.20       200
#            3       0.46      0.38      0.41       199
#            4       0.57      0.82      0.67       200
#            5       0.54      0.43      0.48       199
#            6       0.51      0.67      0.57       200
#
#     accuracy                           0.60      1396
#    macro avg       0.59      0.60      0.57      1396
# weighted avg       0.59      0.60      0.57      1396

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
from tensorflow.keras.models import load_model
model = load_model('/content/best_model9.h5')

# %%
model.evaluate(test_datatset)
# Out:
# 1396/1396 [==============================] - 38s 27ms/step - loss: 1.2451 - accuracy: 0.5587
# [1.2451190948486328, 0.5587392449378967]

# %%
pred = model.predict(test_datatset)
pred = np.argmax(pred, axis=1)
cm = confusion_matrix(test_datatset.classes, pred)
sns.heatmap(cm, annot=True);

# %%
print(classification_report(test_datatset.classes, pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.55      0.79      0.65       198
#            1       0.81      0.94      0.87       200
#            2       0.53      0.09      0.15       200
#            3       0.40      0.47      0.43       199
#            4       0.56      0.69      0.62       200
#            5       0.55      0.33      0.42       199
#            6       0.49      0.60      0.54       200
#
#     accuracy                           0.56      1396
#    macro avg       0.56      0.56      0.52      1396
# weighted avg       0.56      0.56      0.52      1396

# %%
network.save('network.h5')

# %%
net = load_model('/content/network.h5')

# %%
net.evaluate(test_datatset)
# Out:
# 1396/1396 [==============================] - 35s 25ms/step - loss: 1.1453 - accuracy: 0.5974
# [1.1453189849853516, 0.5974212288856506]

# %%
pre = net.predict(test_datatset)
pre = np.argmax(pre, axis=1)
cm = confusion_matrix(test_datatset.classes, pre)
sns.heatmap(cm, annot=True);

# %%
print(classification_report(test_datatset.classes, pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.55      0.79      0.65       198
#            1       0.81      0.94      0.87       200
#            2       0.53      0.09      0.15       200
#            3       0.40      0.47      0.43       199
#            4       0.56      0.69      0.62       200
#            5       0.55      0.33      0.42       199
#            6       0.49      0.60      0.54       200
#
#     accuracy                           0.56      1396
#    macro avg       0.56      0.56      0.52      1396
# weighted avg       0.56      0.56      0.52      1396
