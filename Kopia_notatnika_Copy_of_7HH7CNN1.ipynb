# %% [markdown]
# <a href="https://colab.research.google.com/github/SebastianKosmider/Praktyki/blob/main/Kopia_notatnika_Copy_of_7HH7CNN1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install h5py
# !pip install typing-extensions
# !pip install wheel
# Out:
# Requirement already satisfied: h5py in /usr/local/lib/python3.10/dist-packages (3.8.0)
# Requirement already satisfied: numpy>=1.14.5 in /usr/local/lib/python3.10/dist-packages (from h5py) (1.22.4)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (4.7.1)
# Requirement already satisfied: wheel in /usr/local/lib/python3.10/dist-packages (0.41.0)

# %%
# !pip install tensorflow==2.8
# Out:
# Collecting tensorflow==2.8
#   Downloading tensorflow-2.8.0-cp310-cp310-manylinux2010_x86_64.whl (497.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 497.6/497.6 MB 2.1 MB/s eta 0:00:00
# Requirement already satisfied: absl-py>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8) (1.6.3)
# Requirement already satisfied: flatbuffers>=1.12 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8) (23.5.26)
# Requirement already satisfied: gast>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8) (0.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8) (3.8.0)
# Collecting keras-preprocessing>=1.1.1 (from tensorflow==2.8)
#   Downloading Keras_Preprocessing-1.1.2-py2.py3-none-any.whl (42 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.6/42.6 kB 1.3 MB/s eta 0:00:00
# Requirement already satisfied: libclang>=9.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8) (16.0.6)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8) (1.22.4)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8) (3.3.0)
# Requirement already satisfied: protobuf>=3.9.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8) (3.20.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8) (67.7.2)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8) (2.3.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8) (4.7.1)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8) (1.14.1)
# Collecting tensorboard<2.9,>=2.8 (from tensorflow==2.8)
#   Downloading tensorboard-2.8.0-py3-none-any.whl (5.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.8/5.8 MB 51.1 MB/s eta 0:00:00
# Collecting tf-estimator-nightly==2.8.0.dev2021122109 (from tensorflow==2.8)
#   Downloading tf_estimator_nightly-2.8.0.dev2021122109-py2.py3-none-any.whl (462 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 462.5/462.5 kB 25.7 MB/s eta 0:00:00
# Collecting keras<2.9,>=2.8.0rc0 (from tensorflow==2.8)
#   Downloading keras-2.8.0-py2.py3-none-any.whl (1.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 37.4 MB/s eta 0:00:00
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8) (0.32.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8) (1.56.2)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow==2.8) (0.41.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.9,>=2.8->tensorflow==2.8) (2.17.3)
# Collecting google-auth-oauthlib<0.5,>=0.4.1 (from tensorboard<2.9,>=2.8->tensorflow==2.8)
#   Downloading google_auth_oauthlib-0.4.6-py2.py3-none-any.whl (18 kB)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.9,>=2.8->tensorflow==2.8) (3.4.4)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.9,>=2.8->tensorflow==2.8) (2.27.1)
# Collecting tensorboard-data-server<0.7.0,>=0.6.0 (from tensorboard<2.9,>=2.8->tensorflow==2.8)
#   Downloading tensorboard_data_server-0.6.1-py3-none-manylinux2010_x86_64.whl (4.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 39.8 MB/s eta 0:00:00
# Collecting tensorboard-plugin-wit>=1.6.0 (from tensorboard<2.9,>=2.8->tensorflow==2.8)
#   Downloading tensorboard_plugin_wit-1.8.1-py3-none-any.whl (781 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 781.3/781.3 kB 39.3 MB/s eta 0:00:00
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.9,>=2.8->tensorflow==2.8) (2.3.6)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow==2.8) (5.3.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow==2.8) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow==2.8) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow==2.8) (1.3.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow==2.8) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow==2.8) (2023.7.22)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow==2.8) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow==2.8) (3.4)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=0.11.15->tensorboard<2.9,>=2.8->tensorflow==2.8) (2.1.3)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow==2.8) (0.5.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow==2.8) (3.2.2)
# Installing collected packages: tf-estimator-nightly, tensorboard-plugin-wit, keras, tensorboard-data-server, keras-preprocessing, google-auth-oauthlib, tensorboard, tensorflow
#   Attempting uninstall: keras
#     Found existing installation: keras 2.12.0
#     Uninstalling keras-2.12.0:
#       Successfully uninstalled keras-2.12.0
#   Attempting uninstall: tensorboard-data-server
#     Found existing installation: tensorboard-data-server 0.7.1
#     Uninstalling tensorboard-data-server-0.7.1:
#       Successfully uninstalled tensorboard-data-server-0.7.1
#   Attempting uninstall: google-auth-oauthlib
#     Found existing installation: google-auth-oauthlib 1.0.0
#     Uninstalling google-auth-oauthlib-1.0.0:
#       Successfully uninstalled google-auth-oauthlib-1.0.0
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.12.3
#     Uninstalling tensorboard-2.12.3:
#       Successfully uninstalled tensorboard-2.12.3
#   Attempting uninstall: tensorflow
#     Found existing installation: tensorflow 2.12.0
#     Uninstalling tensorflow-2.12.0:
#       Successfully uninstalled tensorflow-2.12.0
# Successfully installed google-auth-oauthlib-0.4.6 keras-2.8.0 keras-preprocessing-1.1.2 tensorboard-2.8.0 tensorboard-data-server-0.6.1 tensorboard-plugin-wit-1.8.1 tensorflow-2.8.0 tf-estimator-nightly-2.8.0.dev2021122109

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import zipfile
import numpy as np
import cv2
from google.colab.patches import cv2_imshow
import tensorflow as tf
from tensorflow.keras.callbacks import ReduceLROnPlateau
from tensorflow.keras import regularizers
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPool2D, Flatten, Dense, BatchNormalization, Dropout
from tensorflow.keras.preprocessing.image import ImageDataGenerator
tf.__version__
# Out:
# '2.8.0'

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
path = '/content/drive/MyDrive/praktyki/rawDataSingleMolecule/gotowe.zip'
zip_object = zipfile.ZipFile(file=path, mode='r')
zip_object.extractall('./')
zip_object.close()

# %%
training_generator = ImageDataGenerator(rescale=1./255,
                                        horizontal_flip=True,
                                        vertical_flip=True)

# %%
train_dataset = training_generator.flow_from_directory('/content/gotowe/train_set',
                                                       target_size = (256, 256),
                                                       batch_size = 10,
                                                       color_mode='rgb',
                                                       class_mode = 'categorical',
                                                       shuffle = True)
# Out:
# Found 11158 images belonging to 7 classes.

# %%
train_dataset.classes
# Out:
# array([0, 0, 0, ..., 6, 6, 6], dtype=int32)

# %%
train_dataset.class_indices
# Out:
# {'nematyk': 0,
#  'smektyk_C': 1,
#  'smektyk_F': 2,
#  'smektyk_GMosaic': 3,
#  'smektyk_GSchliren': 4,
#  'smektyk_H': 5,
#  'smektyk_I': 6}

# %%
test_generator = ImageDataGenerator(rescale=1./255)
val_generator = ImageDataGenerator(rescale=1./255)

# %%
validation_dataset = val_generator.flow_from_directory('/content/gotowe/val_set',
                                                        target_size=(256, 256),
                                                        batch_size=1,
                                                        class_mode='categorical',
                                                        color_mode='rgb',
                                                        shuffle=True) # set as validation data
# Out:
# Found 1395 images belonging to 7 classes.

# %%
L2 = 0.00001

# %%
test_datatset = test_generator.flow_from_directory('/content/gotowe/test_set',
                                                   target_size = (256, 256),
                                                   batch_size = 1,
                                                   color_mode='rgb',
                                                   class_mode = 'categorical',
                                                   shuffle = False)
# Out:
# Found 1396 images belonging to 7 classes.

# %%
initializer1 = tf.keras.initializers.HeNormal()
initializer2 = tf.keras.initializers.GlorotUniform()

# %%
network = Sequential()
network.add(Conv2D(filters=32, kernel_size=(3,3), activation = 'relu', input_shape = (256,256,3), kernel_initializer=initializer1))
network.add(BatchNormalization())
network.add(MaxPool2D(pool_size=(2,2)))

network.add(Conv2D(filters=64, kernel_size=(3,3), activation = 'relu', padding='same', kernel_initializer=initializer1))
network.add(Conv2D(filters=64, kernel_size=(3,3), activation = 'relu', padding='same', kernel_initializer=initializer1))
network.add(BatchNormalization())
network.add(MaxPool2D(pool_size=(2,2)))

network.add(Conv2D(filters=128, kernel_size=(3,3), activation = 'relu', padding='same', kernel_initializer=initializer1))
network.add(Conv2D(filters=128, kernel_size=(3,3), activation = 'relu', padding='same', kernel_initializer=initializer1))
network.add(BatchNormalization())
network.add(MaxPool2D(pool_size=(2,2)))

network.add(Conv2D(filters=256, kernel_size=(1,1), activation = 'relu', padding='same', kernel_initializer=initializer1))
network.add(Conv2D(filters=256, kernel_size=(1,1), activation = 'relu', padding='same', kernel_initializer=initializer1))
network.add(BatchNormalization())
network.add(MaxPool2D(pool_size=(2,2)))

network.add(Flatten())

#network.add(Dropout(0.2))
network.add(Dense(units = 256, activation = 'relu', kernel_initializer=initializer1))
network.add(BatchNormalization())
network.add(Dense(units = 128, activation = 'relu', kernel_initializer=initializer1))
network.add(BatchNormalization())
network.add(Dense(units = 64, activation = 'relu', kernel_initializer=initializer1))
network.add(BatchNormalization())
network.add(Dense(units = 32, activation = 'relu', kernel_initializer=initializer1, kernel_regularizer=tf.keras.regularizers.L1L2()))
network.add(BatchNormalization())
network.add(Dense(units = 7, activation = 'softmax', kernel_initializer=initializer2))
network.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 254, 254, 32)      896
#
#  batch_normalization (BatchN  (None, 254, 254, 32)     128
#  ormalization)
#
#  max_pooling2d (MaxPooling2D  (None, 127, 127, 32)     0
#  )
#
#  conv2d_1 (Conv2D)           (None, 127, 127, 64)      18496
#
#  conv2d_2 (Conv2D)           (None, 127, 127, 64)      36928
#
#  batch_normalization_1 (Batc  (None, 127, 127, 64)     256
#  hNormalization)
#
#  max_pooling2d_1 (MaxPooling  (None, 63, 63, 64)       0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 63, 63, 128)       73856
#
#  conv2d_4 (Conv2D)           (None, 63, 63, 128)       147584
#
#  batch_normalization_2 (Batc  (None, 63, 63, 128)      512
#  hNormalization)
#
#  max_pooling2d_2 (MaxPooling  (None, 31, 31, 128)      0
#  2D)
#
#  conv2d_5 (Conv2D)           (None, 31, 31, 256)       33024
#
#  conv2d_6 (Conv2D)           (None, 31, 31, 256)       65792
#
#  batch_normalization_3 (Batc  (None, 31, 31, 256)      1024
#  hNormalization)
#
#  max_pooling2d_3 (MaxPooling  (None, 15, 15, 256)      0
#  2D)
#
#  flatten (Flatten)           (None, 57600)             0
#
#  dense (Dense)               (None, 256)               14745856
#
#  batch_normalization_4 (Batc  (None, 256)              1024
#  hNormalization)
#
#  dense_1 (Dense)             (None, 128)               32896
#
#  batch_normalization_5 (Batc  (None, 128)              512
#  hNormalization)
#
#  dense_2 (Dense)             (None, 64)                8256
#
#  batch_normalization_6 (Batc  (None, 64)               256
#  hNormalization)
#
#  dense_3 (Dense)             (None, 32)                2080
#
#  batch_normalization_7 (Batc  (None, 32)               128
#  hNormalization)
#
#  dense_4 (Dense)             (None, 7)                 231
#
# =================================================================
# Total params: 15,169,735
# Trainable params: 15,167,815
# Non-trainable params: 1,920
# _________________________________________________________________

# %%
from tensorflow.keras.optimizers import Adam
#opt = Adam(lr=0.005)
opt = Adam()
network.compile(optimizer='Adam', loss='categorical_crossentropy', metrics = ['accuracy'])

# %%
es = EarlyStopping(monitor = 'val_accuracy', min_delta = 0.001, patience = 20, verbose =1)
model_cp = ModelCheckpoint(filepath = 'best_model1.h5', monitor = 'val_accuracy', save_best_only = True, verbose = 1)
learning_rate_reduction = ReduceLROnPlateau(monitor='val_accuracy', patience = 5, verbose=1, factor=0.5, min_lr=0.00001)

# %%
history = network.fit_generator(train_dataset,
                                steps_per_epoch = 50,
                                validation_data = validation_dataset,
                                validation_steps = 50,
                                epochs=100,
                                callbacks=[es, model_cp, learning_rate_reduction])
# Out:
# <ipython-input-20-d45876fe1552>:1: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history = network.fit_generator(train_dataset,
# Epoch 1/100
# 50/50 [==============================] - ETA: 0s - loss: 1.9036 - accuracy: 0.3120
# Epoch 1: val_accuracy improved from -inf to 0.18000, saving model to best_model1.h5
# 50/50 [==============================] - 230s 5s/step - loss: 1.9036 - accuracy: 0.3120 - val_loss: 4.2727 - val_accuracy: 0.1800 - lr: 0.0010
# Epoch 2/100
# 50/50 [==============================] - ETA: 0s - loss: 1.4133 - accuracy: 0.4839
# Epoch 2: val_accuracy improved from 0.18000 to 0.36000, saving model to best_model1.h5
# 50/50 [==============================] - 224s 4s/step - loss: 1.4133 - accuracy: 0.4839 - val_loss: 1.7047 - val_accuracy: 0.3600 - lr: 0.0010
# Epoch 3/100
# 50/50 [==============================] - ETA: 0s - loss: 1.3103 - accuracy: 0.5480
# Epoch 3: val_accuracy did not improve from 0.36000
# 50/50 [==============================] - 220s 4s/step - loss: 1.3103 - accuracy: 0.5480 - val_loss: 2.8007 - val_accuracy: 0.3200 - lr: 0.0010
# Epoch 4/100
# 50/50 [==============================] - ETA: 0s - loss: 1.3800 - accuracy: 0.4880
# Epoch 4: val_accuracy did not improve from 0.36000
# 50/50 [==============================] - 223s 4s/step - loss: 1.3800 - accuracy: 0.4880 - val_loss: 2.3038 - val_accuracy: 0.3600 - lr: 0.0010
# Epoch 5/100
# 50/50 [==============================] - ETA: 0s - loss: 1.1465 - accuracy: 0.5840
# Epoch 5: val_accuracy improved from 0.36000 to 0.54000, saving model to best_model1.h5
# 50/50 [==============================] - 224s 5s/step - loss: 1.1465 - accuracy: 0.5840 - val_loss: 1.1448 - val_accuracy: 0.5400 - lr: 0.0010
# Epoch 6/100
# 50/50 [==============================] - ETA: 0s - loss: 1.1482 - accuracy: 0.5700
# Epoch 6: val_accuracy did not improve from 0.54000
# 50/50 [==============================] - 219s 4s/step - loss: 1.1482 - accuracy: 0.5700 - val_loss: 1.4501 - val_accuracy: 0.4000 - lr: 0.0010
# Epoch 7/100
# 50/50 [==============================] - ETA: 0s - loss: 1.1949 - accuracy: 0.5780
# Epoch 7: val_accuracy improved from 0.54000 to 0.60000, saving model to best_model1.h5
# 50/50 [==============================] - 226s 5s/step - loss: 1.1949 - accuracy: 0.5780 - val_loss: 1.1189 - val_accuracy: 0.6000 - lr: 0.0010
# Epoch 8/100
# 50/50 [==============================] - ETA: 0s - loss: 0.9830 - accuracy: 0.6700
# Epoch 8: val_accuracy did not improve from 0.60000
# 50/50 [==============================] - 219s 4s/step - loss: 0.9830 - accuracy: 0.6700 - val_loss: 1.2459 - val_accuracy: 0.5800 - lr: 0.0010
# Epoch 9/100
# 50/50 [==============================] - ETA: 0s - loss: 1.0642 - accuracy: 0.6260
# Epoch 9: val_accuracy improved from 0.60000 to 0.66000, saving model to best_model1.h5
# 50/50 [==============================] - 223s 4s/step - loss: 1.0642 - accuracy: 0.6260 - val_loss: 0.9905 - val_accuracy: 0.6600 - lr: 0.0010
# Epoch 10/100
# 50/50 [==============================] - ETA: 0s - loss: 0.9783 - accuracy: 0.6600
# Epoch 10: val_accuracy did not improve from 0.66000
# 50/50 [==============================] - 222s 4s/step - loss: 0.9783 - accuracy: 0.6600 - val_loss: 1.0476 - val_accuracy: 0.6200 - lr: 0.0010
# Epoch 11/100
# 50/50 [==============================] - ETA: 0s - loss: 1.0797 - accuracy: 0.6280
# Epoch 11: val_accuracy improved from 0.66000 to 0.72000, saving model to best_model1.h5
# 50/50 [==============================] - 225s 5s/step - loss: 1.0797 - accuracy: 0.6280 - val_loss: 0.7717 - val_accuracy: 0.7200 - lr: 0.0010
# Epoch 12/100
# 50/50 [==============================] - ETA: 0s - loss: 0.9343 - accuracy: 0.6760
# Epoch 12: val_accuracy improved from 0.72000 to 0.74000, saving model to best_model1.h5
# 50/50 [==============================] - 224s 4s/step - loss: 0.9343 - accuracy: 0.6760 - val_loss: 0.7356 - val_accuracy: 0.7400 - lr: 0.0010
# Epoch 13/100
# 50/50 [==============================] - ETA: 0s - loss: 1.0473 - accuracy: 0.6100
# Epoch 13: val_accuracy did not improve from 0.74000
# 50/50 [==============================] - 224s 5s/step - loss: 1.0473 - accuracy: 0.6100 - val_loss: 0.8522 - val_accuracy: 0.6600 - lr: 0.0010
# Epoch 14/100
# 50/50 [==============================] - ETA: 0s - loss: 0.9655 - accuracy: 0.6400
# Epoch 14: val_accuracy improved from 0.74000 to 0.76000, saving model to best_model1.h5
# 50/50 [==============================] - 224s 5s/step - loss: 0.9655 - accuracy: 0.6400 - val_loss: 0.6790 - val_accuracy: 0.7600 - lr: 0.0010
# Epoch 15/100
# 50/50 [==============================] - ETA: 0s - loss: 0.8714 - accuracy: 0.6660
# Epoch 15: val_accuracy did not improve from 0.76000
# 50/50 [==============================] - 224s 4s/step - loss: 0.8714 - accuracy: 0.6660 - val_loss: 0.6883 - val_accuracy: 0.7600 - lr: 0.0010
# Epoch 16/100
# 50/50 [==============================] - ETA: 0s - loss: 0.9740 - accuracy: 0.6260
# Epoch 16: val_accuracy did not improve from 0.76000
# 50/50 [==============================] - 223s 4s/step - loss: 0.9740 - accuracy: 0.6260 - val_loss: 0.9527 - val_accuracy: 0.6800 - lr: 0.0010
# Epoch 17/100
# 50/50 [==============================] - ETA: 0s - loss: 1.0631 - accuracy: 0.6180
# Epoch 17: val_accuracy did not improve from 0.76000
# 50/50 [==============================] - 220s 4s/step - loss: 1.0631 - accuracy: 0.6180 - val_loss: 0.9976 - val_accuracy: 0.7400 - lr: 0.0010
# Epoch 18/100
# 50/50 [==============================] - ETA: 0s - loss: 0.9131 - accuracy: 0.6300
# Epoch 18: val_accuracy did not improve from 0.76000
# 50/50 [==============================] - 223s 4s/step - loss: 0.9131 - accuracy: 0.6300 - val_loss: 0.8297 - val_accuracy: 0.6600 - lr: 0.0010
# Epoch 19/100
# 50/50 [==============================] - ETA: 0s - loss: 1.0072 - accuracy: 0.6320
# Epoch 19: val_accuracy did not improve from 0.76000
#
# Epoch 19: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 50/50 [==============================] - 220s 4s/step - loss: 1.0072 - accuracy: 0.6320 - val_loss: 0.8131 - val_accuracy: 0.7000 - lr: 0.0010
# Epoch 20/100
# 50/50 [==============================] - ETA: 0s - loss: 0.8780 - accuracy: 0.6840
# Epoch 20: val_accuracy did not improve from 0.76000
# 50/50 [==============================] - 223s 4s/step - loss: 0.8780 - accuracy: 0.6840 - val_loss: 0.8596 - val_accuracy: 0.7000 - lr: 5.0000e-04
# Epoch 21/100
# 50/50 [==============================] - ETA: 0s - loss: 0.8539 - accuracy: 0.6860
# Epoch 21: val_accuracy did not improve from 0.76000
# 50/50 [==============================] - 223s 4s/step - loss: 0.8539 - accuracy: 0.6860 - val_loss: 0.5926 - val_accuracy: 0.7600 - lr: 5.0000e-04
# Epoch 22/100
# 50/50 [==============================] - ETA: 0s - loss: 0.9675 - accuracy: 0.6680
# Epoch 22: val_accuracy did not improve from 0.76000
# 50/50 [==============================] - 224s 5s/step - loss: 0.9675 - accuracy: 0.6680 - val_loss: 0.9079 - val_accuracy: 0.7000 - lr: 5.0000e-04
# Epoch 23/100
# 50/50 [==============================] - ETA: 0s - loss: 0.9571 - accuracy: 0.6580
# Epoch 23: val_accuracy did not improve from 0.76000
# 50/50 [==============================] - 224s 4s/step - loss: 0.9571 - accuracy: 0.6580 - val_loss: 0.9706 - val_accuracy: 0.6800 - lr: 5.0000e-04
# Epoch 24/100
# 50/50 [==============================] - ETA: 0s - loss: 0.8795 - accuracy: 0.6740
# Epoch 24: val_accuracy did not improve from 0.76000
#
# Epoch 24: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 50/50 [==============================] - 224s 4s/step - loss: 0.8795 - accuracy: 0.6740 - val_loss: 0.8629 - val_accuracy: 0.6800 - lr: 5.0000e-04
# Epoch 25/100
# 50/50 [==============================] - ETA: 0s - loss: 0.8070 - accuracy: 0.7100
# Epoch 25: val_accuracy improved from 0.76000 to 0.82000, saving model to best_model1.h5
# 50/50 [==============================] - 223s 4s/step - loss: 0.8070 - accuracy: 0.7100 - val_loss: 0.7695 - val_accuracy: 0.8200 - lr: 2.5000e-04
# Epoch 26/100
# 50/50 [==============================] - ETA: 0s - loss: 0.8545 - accuracy: 0.6800
# Epoch 26: val_accuracy improved from 0.82000 to 0.84000, saving model to best_model1.h5
# 50/50 [==============================] - 221s 4s/step - loss: 0.8545 - accuracy: 0.6800 - val_loss: 0.5774 - val_accuracy: 0.8400 - lr: 2.5000e-04
# Epoch 27/100
# 50/50 [==============================] - ETA: 0s - loss: 0.8528 - accuracy: 0.7080
# Epoch 27: val_accuracy improved from 0.84000 to 0.86000, saving model to best_model1.h5
# 50/50 [==============================] - 224s 4s/step - loss: 0.8528 - accuracy: 0.7080 - val_loss: 0.5158 - val_accuracy: 0.8600 - lr: 2.5000e-04
# Epoch 28/100
# 50/50 [==============================] - ETA: 0s - loss: 0.8470 - accuracy: 0.6680
# Epoch 28: val_accuracy did not improve from 0.86000
# 50/50 [==============================] - 224s 4s/step - loss: 0.8470 - accuracy: 0.6680 - val_loss: 0.8444 - val_accuracy: 0.7600 - lr: 2.5000e-04
# Epoch 29/100
# 50/50 [==============================] - ETA: 0s - loss: 0.7032 - accuracy: 0.7651
# Epoch 29: val_accuracy did not improve from 0.86000
# 50/50 [==============================] - 220s 4s/step - loss: 0.7032 - accuracy: 0.7651 - val_loss: 0.5157 - val_accuracy: 0.8000 - lr: 2.5000e-04
# Epoch 30/100
# 50/50 [==============================] - ETA: 0s - loss: 0.8003 - accuracy: 0.7220
# Epoch 30: val_accuracy did not improve from 0.86000
# 50/50 [==============================] - 223s 4s/step - loss: 0.8003 - accuracy: 0.7220 - val_loss: 0.6144 - val_accuracy: 0.7600 - lr: 2.5000e-04
# Epoch 31/100
# 50/50 [==============================] - ETA: 0s - loss: 0.6967 - accuracy: 0.7480
# Epoch 31: val_accuracy did not improve from 0.86000
# 50/50 [==============================] - 223s 4s/step - loss: 0.6967 - accuracy: 0.7480 - val_loss: 0.4152 - val_accuracy: 0.8200 - lr: 2.5000e-04
# Epoch 32/100
# 50/50 [==============================] - ETA: 0s - loss: 0.7417 - accuracy: 0.7320
# Epoch 32: val_accuracy improved from 0.86000 to 0.88000, saving model to best_model1.h5
# 50/50 [==============================] - 220s 4s/step - loss: 0.7417 - accuracy: 0.7320 - val_loss: 0.4283 - val_accuracy: 0.8800 - lr: 2.5000e-04
# Epoch 33/100
# 50/50 [==============================] - ETA: 0s - loss: 0.7327 - accuracy: 0.7480
# Epoch 33: val_accuracy did not improve from 0.88000
# 50/50 [==============================] - 224s 4s/step - loss: 0.7327 - accuracy: 0.7480 - val_loss: 0.4708 - val_accuracy: 0.7800 - lr: 2.5000e-04
# Epoch 34/100
# 50/50 [==============================] - ETA: 0s - loss: 0.7509 - accuracy: 0.7240
# Epoch 34: val_accuracy did not improve from 0.88000
# 50/50 [==============================] - 224s 4s/step - loss: 0.7509 - accuracy: 0.7240 - val_loss: 0.5748 - val_accuracy: 0.8200 - lr: 2.5000e-04
# Epoch 35/100
# 50/50 [==============================] - ETA: 0s - loss: 0.8094 - accuracy: 0.7080
# Epoch 35: val_accuracy did not improve from 0.88000
# 50/50 [==============================] - 222s 4s/step - loss: 0.8094 - accuracy: 0.7080 - val_loss: 0.7736 - val_accuracy: 0.7400 - lr: 2.5000e-04
# Epoch 36/100
# 50/50 [==============================] - ETA: 0s - loss: 0.6852 - accuracy: 0.7380
# Epoch 36: val_accuracy did not improve from 0.88000
# 50/50 [==============================] - 223s 4s/step - loss: 0.6852 - accuracy: 0.7380 - val_loss: 0.5310 - val_accuracy: 0.8000 - lr: 2.5000e-04
# Epoch 37/100
# 50/50 [==============================] - ETA: 0s - loss: 0.7606 - accuracy: 0.7360
# Epoch 37: val_accuracy did not improve from 0.88000
#
# Epoch 37: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 50/50 [==============================] - 224s 4s/step - loss: 0.7606 - accuracy: 0.7360 - val_loss: 0.6632 - val_accuracy: 0.8000 - lr: 2.5000e-04
# Epoch 38/100
# 50/50 [==============================] - ETA: 0s - loss: 0.7593 - accuracy: 0.7320
# Epoch 38: val_accuracy did not improve from 0.88000
# 50/50 [==============================] - 229s 5s/step - loss: 0.7593 - accuracy: 0.7320 - val_loss: 0.5039 - val_accuracy: 0.7800 - lr: 1.2500e-04
# Epoch 39/100
# 50/50 [==============================] - ETA: 0s - loss: 0.7279 - accuracy: 0.7480
# Epoch 39: val_accuracy did not improve from 0.88000
# 50/50 [==============================] - 226s 5s/step - loss: 0.7279 - accuracy: 0.7480 - val_loss: 0.5564 - val_accuracy: 0.8200 - lr: 1.2500e-04
# Epoch 40/100
# 50/50 [==============================] - ETA: 0s - loss: 0.6636 - accuracy: 0.7780
# Epoch 40: val_accuracy did not improve from 0.88000
# 50/50 [==============================] - 226s 4s/step - loss: 0.6636 - accuracy: 0.7780 - val_loss: 0.5056 - val_accuracy: 0.8200 - lr: 1.2500e-04
# Epoch 41/100
# 50/50 [==============================] - ETA: 0s - loss: 0.7088 - accuracy: 0.7560
# Epoch 41: val_accuracy did not improve from 0.88000
# 50/50 [==============================] - 222s 4s/step - loss: 0.7088 - accuracy: 0.7560 - val_loss: 0.7416 - val_accuracy: 0.7400 - lr: 1.2500e-04
# Epoch 42/100
# 50/50 [==============================] - ETA: 0s - loss: 0.7402 - accuracy: 0.7520
# Epoch 42: val_accuracy did not improve from 0.88000
#
# Epoch 42: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 50/50 [==============================] - 225s 4s/step - loss: 0.7402 - accuracy: 0.7520 - val_loss: 0.4960 - val_accuracy: 0.8000 - lr: 1.2500e-04
# Epoch 43/100
# 50/50 [==============================] - ETA: 0s - loss: 0.7030 - accuracy: 0.7640
# Epoch 43: val_accuracy did not improve from 0.88000
# 50/50 [==============================] - 224s 4s/step - loss: 0.7030 - accuracy: 0.7640 - val_loss: 0.5647 - val_accuracy: 0.7400 - lr: 6.2500e-05
# Epoch 44/100
# 50/50 [==============================] - ETA: 0s - loss: 0.6597 - accuracy: 0.7811
# Epoch 44: val_accuracy did not improve from 0.88000
# 50/50 [==============================] - 224s 5s/step - loss: 0.6597 - accuracy: 0.7811 - val_loss: 0.4362 - val_accuracy: 0.8800 - lr: 6.2500e-05
# Epoch 45/100
# 50/50 [==============================] - ETA: 0s - loss: 0.7082 - accuracy: 0.7700
# Epoch 45: val_accuracy did not improve from 0.88000
# 50/50 [==============================] - 225s 4s/step - loss: 0.7082 - accuracy: 0.7700 - val_loss: 0.4653 - val_accuracy: 0.8600 - lr: 6.2500e-05
# Epoch 46/100
# 50/50 [==============================] - ETA: 0s - loss: 0.6868 - accuracy: 0.7780
# Epoch 46: val_accuracy did not improve from 0.88000
# 50/50 [==============================] - 224s 4s/step - loss: 0.6868 - accuracy: 0.7780 - val_loss: 0.5432 - val_accuracy: 0.8400 - lr: 6.2500e-05
# Epoch 47/100
# 50/50 [==============================] - ETA: 0s - loss: 0.6027 - accuracy: 0.7980
# Epoch 47: val_accuracy did not improve from 0.88000
#
# Epoch 47: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 50/50 [==============================] - 223s 4s/step - loss: 0.6027 - accuracy: 0.7980 - val_loss: 0.5009 - val_accuracy: 0.8600 - lr: 6.2500e-05
# Epoch 48/100
# 50/50 [==============================] - ETA: 0s - loss: 0.6973 - accuracy: 0.7420
# Epoch 48: val_accuracy improved from 0.88000 to 0.92000, saving model to best_model1.h5
# 50/50 [==============================] - 225s 4s/step - loss: 0.6973 - accuracy: 0.7420 - val_loss: 0.3031 - val_accuracy: 0.9200 - lr: 3.1250e-05
# Epoch 49/100
# 50/50 [==============================] - ETA: 0s - loss: 0.7092 - accuracy: 0.7440
# Epoch 49: val_accuracy did not improve from 0.92000
# 50/50 [==============================] - 220s 4s/step - loss: 0.7092 - accuracy: 0.7440 - val_loss: 0.6365 - val_accuracy: 0.7600 - lr: 3.1250e-05
# Epoch 50/100
# 50/50 [==============================] - ETA: 0s - loss: 0.7022 - accuracy: 0.7520
# Epoch 50: val_accuracy did not improve from 0.92000
# 50/50 [==============================] - 222s 4s/step - loss: 0.7022 - accuracy: 0.7520 - val_loss: 0.3948 - val_accuracy: 0.8600 - lr: 3.1250e-05
# Epoch 51/100
# 50/50 [==============================] - ETA: 0s - loss: 0.6806 - accuracy: 0.7520
# Epoch 51: val_accuracy did not improve from 0.92000
# 50/50 [==============================] - 219s 4s/step - loss: 0.6806 - accuracy: 0.7520 - val_loss: 0.4293 - val_accuracy: 0.8800 - lr: 3.1250e-05
# Epoch 52/100
# 50/50 [==============================] - ETA: 0s - loss: 0.7043 - accuracy: 0.7380
# Epoch 52: val_accuracy did not improve from 0.92000
# 50/50 [==============================] - 222s 4s/step - loss: 0.7043 - accuracy: 0.7380 - val_loss: 0.5331 - val_accuracy: 0.8200 - lr: 3.1250e-05
# Epoch 53/100
# 50/50 [==============================] - ETA: 0s - loss: 0.6214 - accuracy: 0.7680
# Epoch 53: val_accuracy did not improve from 0.92000
#
# Epoch 53: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 50/50 [==============================] - 221s 4s/step - loss: 0.6214 - accuracy: 0.7680 - val_loss: 0.4446 - val_accuracy: 0.9000 - lr: 3.1250e-05
# Epoch 54/100
# 50/50 [==============================] - ETA: 0s - loss: 0.6669 - accuracy: 0.7500
# Epoch 54: val_accuracy did not improve from 0.92000
# 50/50 [==============================] - 219s 4s/step - loss: 0.6669 - accuracy: 0.7500 - val_loss: 0.5826 - val_accuracy: 0.7400 - lr: 1.5625e-05
# Epoch 55/100
# 50/50 [==============================] - ETA: 0s - loss: 0.6439 - accuracy: 0.7920
# Epoch 55: val_accuracy did not improve from 0.92000
# 50/50 [==============================] - 221s 4s/step - loss: 0.6439 - accuracy: 0.7920 - val_loss: 0.5823 - val_accuracy: 0.8400 - lr: 1.5625e-05
# Epoch 56/100
# 50/50 [==============================] - ETA: 0s - loss: 0.6213 - accuracy: 0.7760
# Epoch 56: val_accuracy did not improve from 0.92000
# 50/50 [==============================] - 220s 4s/step - loss: 0.6213 - accuracy: 0.7760 - val_loss: 0.5325 - val_accuracy: 0.8200 - lr: 1.5625e-05
# Epoch 57/100
# 50/50 [==============================] - ETA: 0s - loss: 0.6522 - accuracy: 0.7711
# Epoch 57: val_accuracy did not improve from 0.92000
# 50/50 [==============================] - 223s 4s/step - loss: 0.6522 - accuracy: 0.7711 - val_loss: 0.5200 - val_accuracy: 0.8000 - lr: 1.5625e-05
# Epoch 58/100
# 50/50 [==============================] - ETA: 0s - loss: 0.5780 - accuracy: 0.8080
# Epoch 58: val_accuracy did not improve from 0.92000
#
# Epoch 58: ReduceLROnPlateau reducing learning rate to 1e-05.
# 50/50 [==============================] - 219s 4s/step - loss: 0.5780 - accuracy: 0.8080 - val_loss: 0.3540 - val_accuracy: 0.9000 - lr: 1.5625e-05
# Epoch 59/100
# 50/50 [==============================] - ETA: 0s - loss: 0.6673 - accuracy: 0.7680
# Epoch 59: val_accuracy did not improve from 0.92000
# 50/50 [==============================] - 222s 4s/step - loss: 0.6673 - accuracy: 0.7680 - val_loss: 0.4781 - val_accuracy: 0.8600 - lr: 1.0000e-05
# Epoch 60/100
# 50/50 [==============================] - ETA: 0s - loss: 0.6354 - accuracy: 0.7860
# Epoch 60: val_accuracy did not improve from 0.92000
# 50/50 [==============================] - 220s 4s/step - loss: 0.6354 - accuracy: 0.7860 - val_loss: 0.5279 - val_accuracy: 0.7800 - lr: 1.0000e-05
# Epoch 61/100
# 50/50 [==============================] - ETA: 0s - loss: 0.6218 - accuracy: 0.7880
# Epoch 61: val_accuracy did not improve from 0.92000
# 50/50 [==============================] - 222s 4s/step - loss: 0.6218 - accuracy: 0.7880 - val_loss: 0.4187 - val_accuracy: 0.9000 - lr: 1.0000e-05
# Epoch 62/100
# 50/50 [==============================] - ETA: 0s - loss: 0.6188 - accuracy: 0.7820
# Epoch 62: val_accuracy did not improve from 0.92000
# 50/50 [==============================] - 222s 4s/step - loss: 0.6188 - accuracy: 0.7820 - val_loss: 0.5109 - val_accuracy: 0.8600 - lr: 1.0000e-05
# Epoch 63/100
# 50/50 [==============================] - 220s 4s/step - loss: 0.6835 - accuracy: 0.7380 - val_loss: 0.4452 - val_accuracy: 0.8800 - lr: 1.0000e-05
# Epoch 64/100
# 50/50 [==============================] - ETA: 0s - loss: 0.6207 - accuracy: 0.7920
# Epoch 64: val_accuracy did not improve from 0.92000
# 50/50 [==============================] - 221s 4s/step - loss: 0.6207 - accuracy: 0.7920 - val_loss: 0.6138 - val_accuracy: 0.8400 - lr: 1.0000e-05
# Epoch 65/100
# 50/50 [==============================] - ETA: 0s - loss: 0.5925 - accuracy: 0.8000
# Epoch 65: val_accuracy did not improve from 0.92000
# 50/50 [==============================] - 219s 4s/step - loss: 0.5925 - accuracy: 0.8000 - val_loss: 0.5640 - val_accuracy: 0.8000 - lr: 1.0000e-05
# Epoch 66/100
# 50/50 [==============================] - ETA: 0s - loss: 0.6274 - accuracy: 0.7760
# Epoch 66: val_accuracy did not improve from 0.92000
# 50/50 [==============================] - 222s 4s/step - loss: 0.6274 - accuracy: 0.7760 - val_loss: 0.3435 - val_accuracy: 0.8800 - lr: 1.0000e-05
# Epoch 67/100
# 50/50 [==============================] - ETA: 0s - loss: 0.7114 - accuracy: 0.7680
# Epoch 67: val_accuracy did not improve from 0.92000
# 50/50 [==============================] - 221s 4s/step - loss: 0.7114 - accuracy: 0.7680 - val_loss: 0.4251 - val_accuracy: 0.9000 - lr: 1.0000e-05
# Epoch 68/100
# 50/50 [==============================] - ETA: 0s - loss: 0.6792 - accuracy: 0.7520
# Epoch 68: val_accuracy did not improve from 0.92000
# 50/50 [==============================] - 219s 4s/step - loss: 0.6792 - accuracy: 0.7520 - val_loss: 0.7809 - val_accuracy: 0.7600 - lr: 1.0000e-05
# Epoch 68: early stopping

# %%
predictions=network.predict(test_datatset)
predictions = np.argmax(predictions, axis=1)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(test_datatset.classes, predictions)
# Out:
# 0.8431232091690545

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(test_datatset.classes, predictions)
sns.heatmap(cm, annot=True);

# %%
from sklearn.metrics import classification_report
print(classification_report(test_datatset.classes, predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      0.98      0.92       198
#            1       0.99      1.00      1.00       200
#            2       0.72      0.86      0.79       200
#            3       0.75      0.52      0.62       199
#            4       0.86      0.90      0.88       200
#            5       0.84      0.77      0.80       199
#            6       0.88      0.87      0.87       200
#
#     accuracy                           0.84      1396
#    macro avg       0.84      0.84      0.84      1396
# weighted avg       0.84      0.84      0.84      1396

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
from tensorflow.keras.models import load_model
model = load_model('/content/best_model1.h5')

# %%
model.evaluate(test_datatset)
# Out:
# 1396/1396 [==============================] - 169s 121ms/step - loss: 0.4798 - accuracy: 0.8417
# [0.47976019978523254, 0.8416905403137207]

# %%
pred = model.predict(test_datatset)
pred = np.argmax(pred, axis=1)
cm = confusion_matrix(test_datatset.classes, pred)
sns.heatmap(cm, annot=True);

# %%
print(classification_report(test_datatset.classes, pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.87      0.96      0.92       198
#            1       1.00      1.00      1.00       200
#            2       0.71      0.85      0.77       200
#            3       0.75      0.57      0.65       199
#            4       0.89      0.86      0.88       200
#            5       0.86      0.75      0.80       199
#            6       0.82      0.89      0.85       200
#
#     accuracy                           0.84      1396
#    macro avg       0.84      0.84      0.84      1396
# weighted avg       0.84      0.84      0.84      1396

# %%
network.save('network.h5')

# %%
net = load_model('/content/network.h5')

# %%
net.evaluate(test_datatset)
# Out:
# 1396/1396 [==============================] - 176s 126ms/step - loss: 0.4578 - accuracy: 0.8431
# [0.4577922523021698, 0.843123197555542]

# %%
pre = net.predict(test_datatset)
pre = np.argmax(pre, axis=1)
cm = confusion_matrix(test_datatset.classes, pre)
sns.heatmap(cm, annot=True);

# %%
print(classification_report(test_datatset.classes, pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.87      0.96      0.92       198
#            1       1.00      1.00      1.00       200
#            2       0.71      0.85      0.77       200
#            3       0.75      0.57      0.65       199
#            4       0.89      0.86      0.88       200
#            5       0.86      0.75      0.80       199
#            6       0.82      0.89      0.85       200
#
#     accuracy                           0.84      1396
#    macro avg       0.84      0.84      0.84      1396
# weighted avg       0.84      0.84      0.84      1396
