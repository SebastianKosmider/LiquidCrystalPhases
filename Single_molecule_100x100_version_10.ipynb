# %% [markdown]
# <a href="https://colab.research.google.com/github/SebastianKosmider/Praktyki/blob/main/Single_molecule_100x100_version_10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install h5py
# !pip install typing-extensions
# !pip install wheel
# Out:
# Requirement already satisfied: h5py in /usr/local/lib/python3.10/dist-packages (3.9.0)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.10/dist-packages (from h5py) (1.23.5)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (4.7.1)
# Requirement already satisfied: wheel in /usr/local/lib/python3.10/dist-packages (0.41.1)

# %%
# !pip install tensorflow==2.8
# Out:
# Collecting tensorflow==2.8
#   Downloading tensorflow-2.8.0-cp310-cp310-manylinux2010_x86_64.whl (497.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 497.6/497.6 MB 2.4 MB/s eta 0:00:00
# Requirement already satisfied: absl-py>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8) (1.6.3)
# Requirement already satisfied: flatbuffers>=1.12 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8) (23.5.26)
# Requirement already satisfied: gast>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8) (0.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8) (3.9.0)
# Collecting keras-preprocessing>=1.1.1 (from tensorflow==2.8)
#   Downloading Keras_Preprocessing-1.1.2-py2.py3-none-any.whl (42 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.6/42.6 kB 3.6 MB/s eta 0:00:00
# Requirement already satisfied: libclang>=9.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8) (16.0.6)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8) (1.23.5)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8) (3.3.0)
# Requirement already satisfied: protobuf>=3.9.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8) (3.20.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8) (67.7.2)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8) (2.3.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8) (4.7.1)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8) (1.14.1)
# Collecting tensorboard<2.9,>=2.8 (from tensorflow==2.8)
#   Downloading tensorboard-2.8.0-py3-none-any.whl (5.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.8/5.8 MB 44.0 MB/s eta 0:00:00
# Collecting tf-estimator-nightly==2.8.0.dev2021122109 (from tensorflow==2.8)
#   Downloading tf_estimator_nightly-2.8.0.dev2021122109-py2.py3-none-any.whl (462 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 462.5/462.5 kB 22.1 MB/s eta 0:00:00
# Collecting keras<2.9,>=2.8.0rc0 (from tensorflow==2.8)
#   Downloading keras-2.8.0-py2.py3-none-any.whl (1.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 47.3 MB/s eta 0:00:00
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8) (0.33.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8) (1.57.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow==2.8) (0.41.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.9,>=2.8->tensorflow==2.8) (2.17.3)
# Collecting google-auth-oauthlib<0.5,>=0.4.1 (from tensorboard<2.9,>=2.8->tensorflow==2.8)
#   Downloading google_auth_oauthlib-0.4.6-py2.py3-none-any.whl (18 kB)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.9,>=2.8->tensorflow==2.8) (3.4.4)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.9,>=2.8->tensorflow==2.8) (2.31.0)
# Collecting tensorboard-data-server<0.7.0,>=0.6.0 (from tensorboard<2.9,>=2.8->tensorflow==2.8)
#   Downloading tensorboard_data_server-0.6.1-py3-none-manylinux2010_x86_64.whl (4.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 61.5 MB/s eta 0:00:00
# Collecting tensorboard-plugin-wit>=1.6.0 (from tensorboard<2.9,>=2.8->tensorflow==2.8)
#   Downloading tensorboard_plugin_wit-1.8.1-py3-none-any.whl (781 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 781.3/781.3 kB 37.1 MB/s eta 0:00:00
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.9,>=2.8->tensorflow==2.8) (2.3.6)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow==2.8) (5.3.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow==2.8) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow==2.8) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow==2.8) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow==2.8) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow==2.8) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow==2.8) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow==2.8) (2023.7.22)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=0.11.15->tensorboard<2.9,>=2.8->tensorflow==2.8) (2.1.3)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow==2.8) (0.5.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow==2.8) (3.2.2)
# Installing collected packages: tf-estimator-nightly, tensorboard-plugin-wit, keras, tensorboard-data-server, keras-preprocessing, google-auth-oauthlib, tensorboard, tensorflow
#   Attempting uninstall: keras
#     Found existing installation: keras 2.12.0
#     Uninstalling keras-2.12.0:
#       Successfully uninstalled keras-2.12.0
#   Attempting uninstall: tensorboard-data-server
#     Found existing installation: tensorboard-data-server 0.7.1
#     Uninstalling tensorboard-data-server-0.7.1:
#       Successfully uninstalled tensorboard-data-server-0.7.1
#   Attempting uninstall: google-auth-oauthlib
#     Found existing installation: google-auth-oauthlib 1.0.0
#     Uninstalling google-auth-oauthlib-1.0.0:
#       Successfully uninstalled google-auth-oauthlib-1.0.0
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.12.3
#     Uninstalling tensorboard-2.12.3:
#       Successfully uninstalled tensorboard-2.12.3
#   Attempting uninstall: tensorflow
#     Found existing installation: tensorflow 2.12.0
#     Uninstalling tensorflow-2.12.0:
#       Successfully uninstalled tensorflow-2.12.0
# Successfully installed google-auth-oauthlib-0.4.6 keras-2.8.0 keras-preprocessing-1.1.2 tensorboard-2.8.0 tensorboard-data-server-0.6.1 tensorboard-plugin-wit-1.8.1 tensorflow-2.8.0 tf-estimator-nightly-2.8.0.dev2021122109

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import zipfile
import numpy as np
import cv2
from google.colab.patches import cv2_imshow
import tensorflow as tf
from tensorflow.keras.callbacks import ReduceLROnPlateau
from tensorflow.keras import regularizers
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPool2D, Flatten, Dense, BatchNormalization, Dropout
from tensorflow.keras.preprocessing.image import ImageDataGenerator
tf.__version__
# Out:
# '2.8.0'

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
path = '/content/drive/MyDrive/praktyki/rawDataSingleMolecule/gotowe.zip'
zip_object = zipfile.ZipFile(file=path, mode='r')
zip_object.extractall('./')
zip_object.close()

# %%
training_generator = ImageDataGenerator(rescale=1./255,
                                        horizontal_flip=True,
                                        vertical_flip=True)

# %%
train_dataset = training_generator.flow_from_directory('/content/gotowe/train_set',
                                                       target_size = (100, 100),
                                                       batch_size = 10,
                                                       color_mode='rgb',
                                                       class_mode = 'categorical',
                                                       shuffle = True)
# Out:
# Found 11158 images belonging to 7 classes.

# %%
train_dataset.classes
# Out:
# array([0, 0, 0, ..., 6, 6, 6], dtype=int32)

# %%
train_dataset.class_indices
# Out:
# {'nematyk': 0,
#  'smektyk_C': 1,
#  'smektyk_F': 2,
#  'smektyk_GMosaic': 3,
#  'smektyk_GSchliren': 4,
#  'smektyk_H': 5,
#  'smektyk_I': 6}

# %%
test_generator = ImageDataGenerator(rescale=1./255)
val_generator = ImageDataGenerator(rescale=1./255)

# %%
validation_dataset = val_generator.flow_from_directory('/content/gotowe/val_set',
                                                        target_size=(100, 100),
                                                        batch_size=1,
                                                        class_mode='categorical',
                                                        color_mode='rgb',
                                                        shuffle=True) # set as validation data
# Out:
# Found 1395 images belonging to 7 classes.

# %%
L2 = 0.00001

# %%
test_datatset = test_generator.flow_from_directory('/content/gotowe/test_set',
                                                   target_size = (100, 100),
                                                   batch_size = 1,
                                                   color_mode='rgb',
                                                   class_mode = 'categorical',
                                                   shuffle = False)
# Out:
# Found 1396 images belonging to 7 classes.

# %%
initializer1 = tf.keras.initializers.HeNormal()
initializer2 = tf.keras.initializers.GlorotUniform()

# %%
network = Sequential()
network.add(Conv2D(filters=16, kernel_size=(3,3), activation = 'relu', input_shape = (100,100,3), kernel_initializer=initializer1))
network.add(BatchNormalization())
network.add(MaxPool2D(pool_size=(2,2)))

network.add(Conv2D(filters=32, kernel_size=(3,3), activation = 'relu', padding='same', kernel_initializer=initializer1))
network.add(BatchNormalization())
network.add(MaxPool2D(pool_size=(2,2)))

network.add(Conv2D(filters=64, kernel_size=(3,3), activation = 'relu', padding='same', kernel_initializer=initializer1))
network.add(BatchNormalization())
network.add(MaxPool2D(pool_size=(2,2)))

network.add(Conv2D(filters=128, kernel_size=(3,3), activation = 'relu', padding='same', kernel_initializer=initializer1))
network.add(BatchNormalization())
network.add(MaxPool2D(pool_size=(2,2)))

network.add(Conv2D(filters=256, kernel_size=(1,1), activation = 'relu', padding='same', kernel_initializer=initializer1))
network.add(Conv2D(filters=256, kernel_size=(1,1), activation = 'relu', padding='same', kernel_initializer=initializer1))
network.add(BatchNormalization())
network.add(MaxPool2D(pool_size=(2,2)))

network.add(Conv2D(filters=512, kernel_size=(1,1), activation = 'relu', padding='same', kernel_initializer=initializer1))
network.add(BatchNormalization())
network.add(MaxPool2D(pool_size=(2,2)))

network.add(Flatten())

network.add(Dropout(0.2))

network.add(Dense(units = 512, activation = 'relu', kernel_initializer=initializer1))
network.add(BatchNormalization())
network.add(Dense(units = 512, activation = 'relu', kernel_initializer=initializer1))
network.add(BatchNormalization())
network.add(Dense(units = 128, activation = 'relu', kernel_initializer=initializer1))
network.add(BatchNormalization())
network.add(Dense(units = 32, activation = 'relu', kernel_initializer=initializer1))
network.add(BatchNormalization())
network.add(Dense(units = 32, activation = 'relu', kernel_initializer=initializer1))
network.add(BatchNormalization())
network.add(Dense(units = 16, activation = 'relu', kernel_initializer=initializer1))
network.add(BatchNormalization())
network.add(Dense(units = 16, activation = 'relu', kernel_initializer=initializer1, kernel_regularizer=tf.keras.regularizers.L1L2()))
network.add(BatchNormalization())
network.add(Dense(units = 7, activation = 'softmax', kernel_initializer=initializer2))
network.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 98, 98, 16)        448
#
#  batch_normalization (BatchN  (None, 98, 98, 16)       64
#  ormalization)
#
#  max_pooling2d (MaxPooling2D  (None, 49, 49, 16)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 49, 49, 32)        4640
#
#  batch_normalization_1 (Batc  (None, 49, 49, 32)       128
#  hNormalization)
#
#  max_pooling2d_1 (MaxPooling  (None, 24, 24, 32)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 24, 24, 64)        18496
#
#  batch_normalization_2 (Batc  (None, 24, 24, 64)       256
#  hNormalization)
#
#  max_pooling2d_2 (MaxPooling  (None, 12, 12, 64)       0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 12, 12, 128)       73856
#
#  batch_normalization_3 (Batc  (None, 12, 12, 128)      512
#  hNormalization)
#
#  max_pooling2d_3 (MaxPooling  (None, 6, 6, 128)        0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 6, 6, 256)         33024
#
#  conv2d_5 (Conv2D)           (None, 6, 6, 256)         65792
#
#  batch_normalization_4 (Batc  (None, 6, 6, 256)        1024
#  hNormalization)
#
#  max_pooling2d_4 (MaxPooling  (None, 3, 3, 256)        0
#  2D)
#
#  conv2d_6 (Conv2D)           (None, 3, 3, 512)         131584
#
#  batch_normalization_5 (Batc  (None, 3, 3, 512)        2048
#  hNormalization)
#
#  max_pooling2d_5 (MaxPooling  (None, 1, 1, 512)        0
#  2D)
#
#  flatten (Flatten)           (None, 512)               0
#
#  dropout (Dropout)           (None, 512)               0
#
#  dense (Dense)               (None, 512)               262656
#
#  batch_normalization_6 (Batc  (None, 512)              2048
#  hNormalization)
#
#  dense_1 (Dense)             (None, 512)               262656
#
#  batch_normalization_7 (Batc  (None, 512)              2048
#  hNormalization)
#
#  dense_2 (Dense)             (None, 128)               65664
#
#  batch_normalization_8 (Batc  (None, 128)              512
#  hNormalization)
#
#  dense_3 (Dense)             (None, 32)                4128
#
#  batch_normalization_9 (Batc  (None, 32)               128
#  hNormalization)
#
#  dense_4 (Dense)             (None, 32)                1056
#
#  batch_normalization_10 (Bat  (None, 32)               128
#  chNormalization)
#
#  dense_5 (Dense)             (None, 16)                528
#
#  batch_normalization_11 (Bat  (None, 16)               64
#  chNormalization)
#
#  dense_6 (Dense)             (None, 16)                272
#
#  batch_normalization_12 (Bat  (None, 16)               64
#  chNormalization)
#
#  dense_7 (Dense)             (None, 7)                 119
#
# =================================================================
# Total params: 933,943
# Trainable params: 929,431
# Non-trainable params: 4,512
# _________________________________________________________________

# %%
from tensorflow.keras.optimizers import Adam
#opt = Adam(lr=0.005)
opt = Adam()
network.compile(optimizer='Adam', loss='categorical_crossentropy', metrics = ['accuracy'])

# %%
es = EarlyStopping(monitor = 'val_accuracy', min_delta = 0.001, patience = 20, verbose =1)
model_cp = ModelCheckpoint(filepath = 'best_model10.h5', monitor = 'val_accuracy', save_best_only = True, verbose = 1)
learning_rate_reduction = ReduceLROnPlateau(monitor='val_accuracy', patience = 5, verbose=1, factor=0.5, min_lr=0.00001)

# %%
history = network.fit_generator(train_dataset,
                                steps_per_epoch = 50,
                                validation_data = validation_dataset,
                                validation_steps = 50,
                                epochs=100,
                                callbacks=[es, model_cp, learning_rate_reduction])
# Out:
# Epoch 1/100
# <ipython-input-18-d45876fe1552>:1: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history = network.fit_generator(train_dataset,
# 50/50 [==============================] - ETA: 0s - loss: 2.1342 - accuracy: 0.1840
# Epoch 1: val_accuracy improved from -inf to 0.10000, saving model to best_model10.h5
# 50/50 [==============================] - 18s 271ms/step - loss: 2.1342 - accuracy: 0.1840 - val_loss: 1.9699 - val_accuracy: 0.1000 - lr: 0.0010
# Epoch 2/100
# 50/50 [==============================] - ETA: 0s - loss: 1.8356 - accuracy: 0.3200
# Epoch 2: val_accuracy improved from 0.10000 to 0.12000, saving model to best_model10.h5
# 50/50 [==============================] - 9s 189ms/step - loss: 1.8356 - accuracy: 0.3200 - val_loss: 2.1118 - val_accuracy: 0.1200 - lr: 0.0010
# Epoch 3/100
# 50/50 [==============================] - ETA: 0s - loss: 1.6380 - accuracy: 0.4020
# Epoch 3: val_accuracy improved from 0.12000 to 0.16000, saving model to best_model10.h5
# 50/50 [==============================] - 12s 245ms/step - loss: 1.6380 - accuracy: 0.4020 - val_loss: 2.0594 - val_accuracy: 0.1600 - lr: 0.0010
# Epoch 4/100
# 50/50 [==============================] - ETA: 0s - loss: 1.6553 - accuracy: 0.3780
# Epoch 4: val_accuracy did not improve from 0.16000
# 50/50 [==============================] - 13s 255ms/step - loss: 1.6553 - accuracy: 0.3780 - val_loss: 2.0450 - val_accuracy: 0.1400 - lr: 0.0010
# Epoch 5/100
# 50/50 [==============================] - ETA: 0s - loss: 1.5279 - accuracy: 0.4360
# Epoch 5: val_accuracy improved from 0.16000 to 0.20000, saving model to best_model10.h5
# 50/50 [==============================] - 11s 209ms/step - loss: 1.5279 - accuracy: 0.4360 - val_loss: 1.9565 - val_accuracy: 0.2000 - lr: 0.0010
# Epoch 6/100
# 50/50 [==============================] - ETA: 0s - loss: 1.4128 - accuracy: 0.4640
# Epoch 6: val_accuracy did not improve from 0.20000
# 50/50 [==============================] - 13s 254ms/step - loss: 1.4128 - accuracy: 0.4640 - val_loss: 1.9733 - val_accuracy: 0.2000 - lr: 0.0010
# Epoch 7/100
# 50/50 [==============================] - ETA: 0s - loss: 1.5028 - accuracy: 0.4560
# Epoch 7: val_accuracy did not improve from 0.20000
# 50/50 [==============================] - 13s 257ms/step - loss: 1.5028 - accuracy: 0.4560 - val_loss: 1.9486 - val_accuracy: 0.2000 - lr: 0.0010
# Epoch 8/100
# 50/50 [==============================] - ETA: 0s - loss: 1.4123 - accuracy: 0.4720
# Epoch 8: val_accuracy improved from 0.20000 to 0.26000, saving model to best_model10.h5
# 50/50 [==============================] - 10s 210ms/step - loss: 1.4123 - accuracy: 0.4720 - val_loss: 1.6676 - val_accuracy: 0.2600 - lr: 0.0010
# Epoch 9/100
# 50/50 [==============================] - ETA: 0s - loss: 1.4308 - accuracy: 0.4500
# Epoch 9: val_accuracy improved from 0.26000 to 0.66000, saving model to best_model10.h5
# 50/50 [==============================] - 12s 233ms/step - loss: 1.4308 - accuracy: 0.4500 - val_loss: 1.1357 - val_accuracy: 0.6600 - lr: 0.0010
# Epoch 10/100
# 50/50 [==============================] - ETA: 0s - loss: 1.3813 - accuracy: 0.5160
# Epoch 10: val_accuracy did not improve from 0.66000
# 50/50 [==============================] - 13s 256ms/step - loss: 1.3813 - accuracy: 0.5160 - val_loss: 1.2744 - val_accuracy: 0.5400 - lr: 0.0010
# Epoch 11/100
# 50/50 [==============================] - ETA: 0s - loss: 1.3154 - accuracy: 0.5120
# Epoch 11: val_accuracy did not improve from 0.66000
# 50/50 [==============================] - 11s 209ms/step - loss: 1.3154 - accuracy: 0.5120 - val_loss: 1.0476 - val_accuracy: 0.6600 - lr: 0.0010
# Epoch 12/100
# 50/50 [==============================] - ETA: 0s - loss: 1.3037 - accuracy: 0.5200
# Epoch 12: val_accuracy did not improve from 0.66000
# 50/50 [==============================] - 13s 255ms/step - loss: 1.3037 - accuracy: 0.5200 - val_loss: 0.9919 - val_accuracy: 0.6400 - lr: 0.0010
# Epoch 13/100
# 50/50 [==============================] - ETA: 0s - loss: 1.3808 - accuracy: 0.5080
# Epoch 13: val_accuracy did not improve from 0.66000
# 50/50 [==============================] - 13s 262ms/step - loss: 1.3808 - accuracy: 0.5080 - val_loss: 1.0512 - val_accuracy: 0.6200 - lr: 0.0010
# Epoch 14/100
# 50/50 [==============================] - ETA: 0s - loss: 1.3234 - accuracy: 0.5160
# Epoch 14: val_accuracy did not improve from 0.66000
#
# Epoch 14: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 50/50 [==============================] - 13s 258ms/step - loss: 1.3234 - accuracy: 0.5160 - val_loss: 1.1593 - val_accuracy: 0.6000 - lr: 0.0010
# Epoch 15/100
# 50/50 [==============================] - ETA: 0s - loss: 1.3328 - accuracy: 0.5120
# Epoch 15: val_accuracy did not improve from 0.66000
# 50/50 [==============================] - 12s 233ms/step - loss: 1.3328 - accuracy: 0.5120 - val_loss: 1.0208 - val_accuracy: 0.6400 - lr: 5.0000e-04
# Epoch 16/100
# 50/50 [==============================] - ETA: 0s - loss: 1.2440 - accuracy: 0.5500
# Epoch 16: val_accuracy did not improve from 0.66000
# 50/50 [==============================] - 13s 257ms/step - loss: 1.2440 - accuracy: 0.5500 - val_loss: 1.0867 - val_accuracy: 0.5800 - lr: 5.0000e-04
# Epoch 17/100
# 50/50 [==============================] - ETA: 0s - loss: 1.2314 - accuracy: 0.5580
# Epoch 17: val_accuracy did not improve from 0.66000
# 50/50 [==============================] - 13s 259ms/step - loss: 1.2314 - accuracy: 0.5580 - val_loss: 1.0000 - val_accuracy: 0.6000 - lr: 5.0000e-04
# Epoch 18/100
# 50/50 [==============================] - ETA: 0s - loss: 1.1868 - accuracy: 0.5840
# Epoch 18: val_accuracy improved from 0.66000 to 0.82000, saving model to best_model10.h5
# 50/50 [==============================] - 15s 302ms/step - loss: 1.1868 - accuracy: 0.5840 - val_loss: 0.6354 - val_accuracy: 0.8200 - lr: 5.0000e-04
# Epoch 19/100
# 50/50 [==============================] - ETA: 0s - loss: 1.2177 - accuracy: 0.5560
# Epoch 19: val_accuracy did not improve from 0.82000
# 50/50 [==============================] - 11s 215ms/step - loss: 1.2177 - accuracy: 0.5560 - val_loss: 1.1700 - val_accuracy: 0.6000 - lr: 5.0000e-04
# Epoch 20/100
# 50/50 [==============================] - ETA: 0s - loss: 1.0822 - accuracy: 0.6260
# Epoch 20: val_accuracy did not improve from 0.82000
# 50/50 [==============================] - 10s 209ms/step - loss: 1.0822 - accuracy: 0.6260 - val_loss: 0.8330 - val_accuracy: 0.7400 - lr: 5.0000e-04
# Epoch 21/100
# 50/50 [==============================] - ETA: 0s - loss: 1.0770 - accuracy: 0.6360
# Epoch 21: val_accuracy did not improve from 0.82000
# 50/50 [==============================] - 12s 250ms/step - loss: 1.0770 - accuracy: 0.6360 - val_loss: 0.8729 - val_accuracy: 0.7200 - lr: 5.0000e-04
# Epoch 22/100
# 50/50 [==============================] - ETA: 0s - loss: 1.2187 - accuracy: 0.5480
# Epoch 22: val_accuracy did not improve from 0.82000
# 50/50 [==============================] - 10s 194ms/step - loss: 1.2187 - accuracy: 0.5480 - val_loss: 1.0838 - val_accuracy: 0.6200 - lr: 5.0000e-04
# Epoch 23/100
# 50/50 [==============================] - ETA: 0s - loss: 1.1607 - accuracy: 0.5720
# Epoch 23: val_accuracy did not improve from 0.82000
#
# Epoch 23: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 50/50 [==============================] - 13s 258ms/step - loss: 1.1607 - accuracy: 0.5720 - val_loss: 0.7030 - val_accuracy: 0.8000 - lr: 5.0000e-04
# Epoch 24/100
# 50/50 [==============================] - ETA: 0s - loss: 1.1234 - accuracy: 0.6040
# Epoch 24: val_accuracy did not improve from 0.82000
# 50/50 [==============================] - 11s 227ms/step - loss: 1.1234 - accuracy: 0.6040 - val_loss: 0.7670 - val_accuracy: 0.7400 - lr: 2.5000e-04
# Epoch 25/100
# 50/50 [==============================] - ETA: 0s - loss: 1.1212 - accuracy: 0.6000
# Epoch 25: val_accuracy did not improve from 0.82000
# 50/50 [==============================] - 13s 260ms/step - loss: 1.1212 - accuracy: 0.6000 - val_loss: 0.6402 - val_accuracy: 0.7400 - lr: 2.5000e-04
# Epoch 26/100
# 50/50 [==============================] - ETA: 0s - loss: 1.1578 - accuracy: 0.5580
# Epoch 26: val_accuracy did not improve from 0.82000
# 50/50 [==============================] - 13s 257ms/step - loss: 1.1578 - accuracy: 0.5580 - val_loss: 0.9720 - val_accuracy: 0.6800 - lr: 2.5000e-04
# Epoch 27/100
# 50/50 [==============================] - ETA: 0s - loss: 1.0226 - accuracy: 0.6220
# Epoch 27: val_accuracy did not improve from 0.82000
# 50/50 [==============================] - 11s 226ms/step - loss: 1.0226 - accuracy: 0.6220 - val_loss: 0.7965 - val_accuracy: 0.7600 - lr: 2.5000e-04
# Epoch 28/100
# 50/50 [==============================] - ETA: 0s - loss: 1.1388 - accuracy: 0.5840
# Epoch 28: val_accuracy did not improve from 0.82000
#
# Epoch 28: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 50/50 [==============================] - 13s 261ms/step - loss: 1.1388 - accuracy: 0.5840 - val_loss: 0.8543 - val_accuracy: 0.6800 - lr: 2.5000e-04
# Epoch 29/100
# 50/50 [==============================] - ETA: 0s - loss: 1.1140 - accuracy: 0.5760
# Epoch 29: val_accuracy did not improve from 0.82000
# 50/50 [==============================] - 13s 267ms/step - loss: 1.1140 - accuracy: 0.5760 - val_loss: 0.9453 - val_accuracy: 0.6600 - lr: 1.2500e-04
# Epoch 30/100
# 50/50 [==============================] - ETA: 0s - loss: 1.0715 - accuracy: 0.6080
# Epoch 30: val_accuracy did not improve from 0.82000
# 50/50 [==============================] - 13s 252ms/step - loss: 1.0715 - accuracy: 0.6080 - val_loss: 0.7479 - val_accuracy: 0.7600 - lr: 1.2500e-04
# Epoch 31/100
# 50/50 [==============================] - ETA: 0s - loss: 1.1745 - accuracy: 0.5780
# Epoch 31: val_accuracy did not improve from 0.82000
# 50/50 [==============================] - 11s 212ms/step - loss: 1.1745 - accuracy: 0.5780 - val_loss: 0.8363 - val_accuracy: 0.7000 - lr: 1.2500e-04
# Epoch 32/100
# 50/50 [==============================] - ETA: 0s - loss: 1.0630 - accuracy: 0.6320
# Epoch 32: val_accuracy did not improve from 0.82000
# 50/50 [==============================] - 13s 259ms/step - loss: 1.0630 - accuracy: 0.6320 - val_loss: 0.7477 - val_accuracy: 0.7400 - lr: 1.2500e-04
# Epoch 33/100
# 50/50 [==============================] - ETA: 0s - loss: 1.1188 - accuracy: 0.5840
# Epoch 33: val_accuracy did not improve from 0.82000
#
# Epoch 33: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 50/50 [==============================] - 11s 212ms/step - loss: 1.1188 - accuracy: 0.5840 - val_loss: 0.9419 - val_accuracy: 0.6800 - lr: 1.2500e-04
# Epoch 34/100
# 50/50 [==============================] - ETA: 0s - loss: 1.0313 - accuracy: 0.6380
# Epoch 34: val_accuracy did not improve from 0.82000
# 50/50 [==============================] - 14s 276ms/step - loss: 1.0313 - accuracy: 0.6380 - val_loss: 0.7720 - val_accuracy: 0.8000 - lr: 6.2500e-05
# Epoch 35/100
# 50/50 [==============================] - ETA: 0s - loss: 1.0204 - accuracy: 0.6400
# Epoch 35: val_accuracy did not improve from 0.82000
# 50/50 [==============================] - 10s 207ms/step - loss: 1.0204 - accuracy: 0.6400 - val_loss: 0.8616 - val_accuracy: 0.6400 - lr: 6.2500e-05
# Epoch 36/100
# 50/50 [==============================] - ETA: 0s - loss: 1.0780 - accuracy: 0.6100
# Epoch 36: val_accuracy did not improve from 0.82000
# 50/50 [==============================] - 13s 263ms/step - loss: 1.0780 - accuracy: 0.6100 - val_loss: 0.7913 - val_accuracy: 0.7800 - lr: 6.2500e-05
# Epoch 37/100
# 50/50 [==============================] - ETA: 0s - loss: 1.0853 - accuracy: 0.6040
# Epoch 37: val_accuracy did not improve from 0.82000
# 50/50 [==============================] - 10s 199ms/step - loss: 1.0853 - accuracy: 0.6040 - val_loss: 0.6508 - val_accuracy: 0.7800 - lr: 6.2500e-05
# Epoch 38/100
# 50/50 [==============================] - ETA: 0s - loss: 1.0886 - accuracy: 0.6260
# Epoch 38: val_accuracy did not improve from 0.82000
#
# Epoch 38: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 50/50 [==============================] - 12s 242ms/step - loss: 1.0886 - accuracy: 0.6260 - val_loss: 0.7774 - val_accuracy: 0.8000 - lr: 6.2500e-05
# Epoch 38: early stopping

# %%
predictions=network.predict(test_datatset)
predictions = np.argmax(predictions, axis=1)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(test_datatset.classes, predictions)
# Out:
# 0.7406876790830945

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(test_datatset.classes, predictions)
sns.heatmap(cm, annot=True);

# %%
from sklearn.metrics import classification_report
print(classification_report(test_datatset.classes, predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.77      0.94      0.84       198
#            1       0.98      0.97      0.97       200
#            2       0.60      0.61      0.61       200
#            3       0.62      0.40      0.49       199
#            4       0.76      0.88      0.81       200
#            5       0.70      0.53      0.61       199
#            6       0.71      0.84      0.77       200
#
#     accuracy                           0.74      1396
#    macro avg       0.73      0.74      0.73      1396
# weighted avg       0.73      0.74      0.73      1396

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
from tensorflow.keras.models import load_model
model = load_model('/content/best_model10.h5')

# %%
model.evaluate(test_datatset)
# Out:
# 1396/1396 [==============================] - 21s 15ms/step - loss: 0.9244 - accuracy: 0.6884
# [0.9243826866149902, 0.6883954405784607]

# %%
pred = model.predict(test_datatset)
pred = np.argmax(pred, axis=1)
cm = confusion_matrix(test_datatset.classes, pred)
sns.heatmap(cm, annot=True);

# %%
print(classification_report(test_datatset.classes, pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.67      0.92      0.78       198
#            1       0.94      0.99      0.96       200
#            2       0.55      0.57      0.56       200
#            3       0.52      0.28      0.37       199
#            4       0.67      0.76      0.71       200
#            5       0.71      0.47      0.57       199
#            6       0.68      0.82      0.75       200
#
#     accuracy                           0.69      1396
#    macro avg       0.68      0.69      0.67      1396
# weighted avg       0.68      0.69      0.67      1396

# %%
network.save('network.h5')

# %%
net = load_model('/content/network.h5')

# %%
net.evaluate(test_datatset)
# Out:
# 1396/1396 [==============================] - 18s 12ms/step - loss: 0.7880 - accuracy: 0.7407
# [0.7879651188850403, 0.7406876683235168]

# %%
pre = net.predict(test_datatset)
pre = np.argmax(pre, axis=1)
cm = confusion_matrix(test_datatset.classes, pre)
sns.heatmap(cm, annot=True);

# %%
print(classification_report(test_datatset.classes, pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.67      0.92      0.78       198
#            1       0.94      0.99      0.96       200
#            2       0.55      0.57      0.56       200
#            3       0.52      0.28      0.37       199
#            4       0.67      0.76      0.71       200
#            5       0.71      0.47      0.57       199
#            6       0.68      0.82      0.75       200
#
#     accuracy                           0.69      1396
#    macro avg       0.68      0.69      0.67      1396
# weighted avg       0.68      0.69      0.67      1396
